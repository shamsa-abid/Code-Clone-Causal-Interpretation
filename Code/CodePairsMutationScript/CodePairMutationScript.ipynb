# %% [markdown]
# #README
#
# **README**
#
#
# *   Execute cell 1 to install asts library and import it. All other cells depend on cell 1.
# *   Upload the **code-samples** zip folder and use cell 2 to unzip the contents.
# Upload the resolved labels csv file.
# *   Create a folder named **mutated-data** to contain the mutated code files.
#
# To get mutated data from specific label values execute the first three scripts below.
# [1. GetMutation method](#scrollTo=FO_zo_t1CWKv&line=1&uniqifier=1)
#
# [2. Process resolved Labels CSV and get mutated code](#scrollTo=myUtvjQQCTzl&line=1&uniqifier=1)
#
# [3. Create mutated CSV files](#scrollTo=7IWTa1EwfYjI)
#
# For the second script, we need to do three things:
# * Upload one of the two resolved labels csv file (*resolved_range_based_labels.csv* or *resolved_value_based_labels.csv*)
# * Set the value of **process_csv_file_name** variable to the uploaded resolved labels csv file
# * Uncomment the code for the specific case for the type of mutation we want to perform. Set the value of variable **value** per case. Cases 1,2 and 3 are for value-based mutations. Cases 5 and 6 are for range-based mutations.
#
# For the third script we must change the **mutated_data_folder** variable name to the **mutated-data** folder name created earlier in which to store the mutated files.
#
# After executing the three scripts we may download some log files, the mutation error report files and success report file manually.
#
# The fourth script copies the files of mutated data to google drive for download. Need to change the value of **drive_folder** variable to your personal google drive folder.
#
# [4. Copy mutated data to google drive](#scrollTo=iWY7llGDv1AV&line=1&uniqifier=1)

# %% [markdown]
# **Install asts library and import**

# %%
! pip3 install asts
import asts
# Out:
# Collecting asts
#   Downloading asts-0.9.7-py3-none-manylinux_2_24_x86_64.whl (35.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 11.0 MB/s eta 0:00:00
# Collecting backports.cached-property (from asts)
#   Downloading backports.cached_property-1.0.2-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from asts) (4.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from asts) (5.9.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from asts) (2.16.1)
# Installing collected packages: backports.cached-property, asts
# Successfully installed asts-0.9.7 backports.cached-property-1.0.2

# %%
# !unzip code-samples.zip
# Out:
# Archive:  code-samples.zip
#    creating: code-samples/.vscode/
#   inflating: code-samples/.vscode/settings.json
#   inflating: code-samples/Clone0.java
#   inflating: code-samples/Clone105.java
#   inflating: code-samples/Clone107.java
#   inflating: code-samples/Clone109.java
#   inflating: code-samples/Clone12.java
#   inflating: code-samples/Clone125.java
#   inflating: code-samples/Clone127.java
#   inflating: code-samples/Clone13.java
#   inflating: code-samples/Clone131.java
#   inflating: code-samples/Clone132.java
#   inflating: code-samples/Clone134.java
#   inflating: code-samples/Clone136.java
#   inflating: code-samples/Clone138.java
#   inflating: code-samples/Clone142.java
#   inflating: code-samples/Clone154.java
#   inflating: code-samples/Clone159.java
#   inflating: code-samples/Clone16.java
#   inflating: code-samples/Clone162.java
#   inflating: code-samples/Clone165.java
#   inflating: code-samples/Clone168.java
#   inflating: code-samples/Clone172.java
#   inflating: code-samples/Clone174.java
#   inflating: code-samples/Clone178.java
#   inflating: code-samples/Clone179.java
#   inflating: code-samples/Clone18.java
#   inflating: code-samples/Clone182.java
#   inflating: code-samples/Clone19.java
#   inflating: code-samples/Clone192.java
#   inflating: code-samples/Clone194.java
#   inflating: code-samples/Clone196.java
#   inflating: code-samples/Clone198.java
#   inflating: code-samples/Clone20.java
#   inflating: code-samples/Clone204.java
#   inflating: code-samples/Clone205.java
#   inflating: code-samples/Clone207.java
#   inflating: code-samples/Clone208.java
#   inflating: code-samples/Clone21.java
#   inflating: code-samples/Clone212.java
#   inflating: code-samples/Clone219.java
#   inflating: code-samples/Clone223.java
#   inflating: code-samples/Clone23.java
#   inflating: code-samples/Clone231.java
#   inflating: code-samples/Clone240.java
#   inflating: code-samples/Clone241.java
#   inflating: code-samples/Clone248.java
#   inflating: code-samples/Clone263.java
#   inflating: code-samples/Clone264.java
#   inflating: code-samples/Clone265.java
#   inflating: code-samples/Clone271.java
#   inflating: code-samples/Clone279.java
#   inflating: code-samples/Clone283.java
#   inflating: code-samples/Clone284.java
#   inflating: code-samples/Clone286.java
#   inflating: code-samples/Clone29.java
#   inflating: code-samples/Clone291.java
#   inflating: code-samples/Clone292.java
#   inflating: code-samples/Clone30.java
#   inflating: code-samples/Clone304.java
#   inflating: code-samples/Clone307.java
#   inflating: code-samples/Clone310.java
#   inflating: code-samples/Clone322.java
#   inflating: code-samples/Clone337.java
#   inflating: code-samples/Clone343.java
#   inflating: code-samples/Clone344.java
#   inflating: code-samples/Clone345.java
#   inflating: code-samples/Clone349.java
#   inflating: code-samples/Clone351.java
#   inflating: code-samples/Clone355.java
#   inflating: code-samples/Clone363.java
#   inflating: code-samples/Clone364.java
#   inflating: code-samples/Clone365.java
#   inflating: code-samples/Clone368.java
#   inflating: code-samples/Clone370.java
#   inflating: code-samples/Clone372.java
#   inflating: code-samples/Clone375.java
#   inflating: code-samples/Clone376.java
#   inflating: code-samples/Clone379.java
#   inflating: code-samples/Clone380.java
#   inflating: code-samples/Clone384.java
#   inflating: code-samples/Clone39.java
#   inflating: code-samples/Clone397.java
#   inflating: code-samples/Clone399.java
#   inflating: code-samples/Clone400.java
#   inflating: code-samples/Clone401.java
#   inflating: code-samples/Clone404.java
#   inflating: code-samples/Clone406.java
#   inflating: code-samples/Clone410.java
#   inflating: code-samples/Clone413.java
#   inflating: code-samples/Clone418.java
#   inflating: code-samples/Clone424.java
#   inflating: code-samples/Clone434.java
#   inflating: code-samples/Clone436.java
#   inflating: code-samples/Clone441.java
#   inflating: code-samples/Clone447.java
#   inflating: code-samples/Clone452.java
#   inflating: code-samples/Clone455.java
#   inflating: code-samples/Clone457.java
#   inflating: code-samples/Clone459.java
#   inflating: code-samples/Clone46.java
#   inflating: code-samples/Clone463.java
#   inflating: code-samples/Clone464.java
#   inflating: code-samples/Clone467.java
#   inflating: code-samples/Clone468.java
#   inflating: code-samples/Clone469.java
#   inflating: code-samples/Clone479.java
#   inflating: code-samples/Clone481.java
#   inflating: code-samples/Clone482.java
#   inflating: code-samples/Clone485.java
#   inflating: code-samples/Clone487.java
#   inflating: code-samples/Clone495.java
#   inflating: code-samples/Clone497.java
#   inflating: code-samples/Clone500.java
#   inflating: code-samples/Clone501.java
#   inflating: code-samples/Clone506.java
#   inflating: code-samples/Clone51.java
#   inflating: code-samples/Clone517.java
#   inflating: code-samples/Clone52.java
#   inflating: code-samples/Clone524.java
#   inflating: code-samples/Clone528.java
#   inflating: code-samples/Clone529.java
#   inflating: code-samples/Clone530.java
#   inflating: code-samples/Clone531.java
#   inflating: code-samples/Clone532.java
#   inflating: code-samples/Clone534.java
#   inflating: code-samples/Clone537.java
#   inflating: code-samples/Clone54.java
#   inflating: code-samples/Clone543.java
#   inflating: code-samples/Clone545.java
#   inflating: code-samples/Clone547.java
#   inflating: code-samples/Clone550.java
#   inflating: code-samples/Clone553.java
#   inflating: code-samples/Clone554.java
#   inflating: code-samples/Clone555.java
#   inflating: code-samples/Clone556.java
#   inflating: code-samples/Clone557.java
#   inflating: code-samples/Clone558.java
#   inflating: code-samples/Clone561.java
#   inflating: code-samples/Clone564.java
#   inflating: code-samples/Clone570.java
#   inflating: code-samples/Clone573.java
#   inflating: code-samples/Clone574.java
#   inflating: code-samples/Clone58.java
#   inflating: code-samples/Clone582.java
#   inflating: code-samples/Clone589.java
#   inflating: code-samples/Clone592.java
#   inflating: code-samples/Clone593.java
#   inflating: code-samples/Clone596.java
#   inflating: code-samples/Clone607.java
#   inflating: code-samples/Clone608.java
#   inflating: code-samples/Clone610.java
#   inflating: code-samples/Clone612.java
#   inflating: code-samples/Clone614.java
#   inflating: code-samples/Clone618.java
#   inflating: code-samples/Clone627.java
#   inflating: code-samples/Clone632.java
#   inflating: code-samples/Clone633.java
#   inflating: code-samples/Clone64.java
#   inflating: code-samples/Clone645.java
#   inflating: code-samples/Clone646.java
#   inflating: code-samples/Clone647.java
#   inflating: code-samples/Clone660.java
#   inflating: code-samples/Clone664.java
#   inflating: code-samples/Clone668.java
#   inflating: code-samples/Clone671.java
#   inflating: code-samples/Clone68.java
#   inflating: code-samples/Clone684.java
#   inflating: code-samples/Clone687.java
#   inflating: code-samples/Clone689.java
#   inflating: code-samples/Clone691.java
#   inflating: code-samples/Clone692.java
#   inflating: code-samples/Clone699.java
#   inflating: code-samples/Clone700.java
#   inflating: code-samples/Clone701.java
#   inflating: code-samples/Clone707.java
#   inflating: code-samples/Clone712.java
#   inflating: code-samples/Clone715.java
#   inflating: code-samples/Clone720.java
#   inflating: code-samples/Clone729.java
#   inflating: code-samples/Clone732.java
#   inflating: code-samples/Clone738.java
#   inflating: code-samples/Clone739.java
#   inflating: code-samples/Clone744.java
#   inflating: code-samples/Clone746.java
#   inflating: code-samples/Clone747.java
#   inflating: code-samples/Clone748.java
#   inflating: code-samples/Clone75.java
#   inflating: code-samples/Clone752.java
#   inflating: code-samples/Clone753.java
#   inflating: code-samples/Clone758.java
#   inflating: code-samples/Clone759.java
#   inflating: code-samples/Clone760.java
#   inflating: code-samples/Clone77.java
#   inflating: code-samples/Clone770.java
#   inflating: code-samples/Clone776.java
#   inflating: code-samples/Clone777.java
#   inflating: code-samples/Clone779.java
#   inflating: code-samples/Clone780.java
#   inflating: code-samples/Clone786.java
#   inflating: code-samples/Clone789.java
#   inflating: code-samples/Clone790.java
#   inflating: code-samples/Clone793.java
#   inflating: code-samples/Clone796.java
#   inflating: code-samples/Clone80.java
#   inflating: code-samples/Clone803.java
#   inflating: code-samples/Clone806.java
#   inflating: code-samples/Clone807.java
#   inflating: code-samples/Clone810.java
#   inflating: code-samples/Clone815.java
#   inflating: code-samples/Clone819.java
#   inflating: code-samples/Clone82.java
#   inflating: code-samples/Clone820.java
#   inflating: code-samples/Clone825.java
#   inflating: code-samples/Clone83.java
#   inflating: code-samples/Clone831.java
#   inflating: code-samples/Clone835.java
#   inflating: code-samples/Clone836.java
#   inflating: code-samples/Clone84.java
#   inflating: code-samples/Clone840.java
#   inflating: code-samples/Clone843.java
#   inflating: code-samples/Clone844.java
#   inflating: code-samples/Clone845.java
#   inflating: code-samples/Clone847.java
#   inflating: code-samples/Clone848.java
#   inflating: code-samples/Clone85.java
#   inflating: code-samples/Clone854.java
#   inflating: code-samples/Clone858.java
#   inflating: code-samples/Clone86.java
#   inflating: code-samples/Clone861.java
#   inflating: code-samples/Clone864.java
#   inflating: code-samples/Clone867.java
#   inflating: code-samples/Clone868.java
#   inflating: code-samples/Clone869.java
#   inflating: code-samples/Clone87.java
#   inflating: code-samples/Clone873.java
#   inflating: code-samples/Clone875.java
#   inflating: code-samples/Clone877.java
#   inflating: code-samples/Clone880.java
#   inflating: code-samples/Clone882.java
#   inflating: code-samples/Clone887.java
#   inflating: code-samples/Clone888.java
#   inflating: code-samples/Clone89.java
#   inflating: code-samples/Clone892.java
#   inflating: code-samples/Clone895.java
#   inflating: code-samples/Clone898.java
#   inflating: code-samples/Clone91.java
#   inflating: code-samples/Clone911.java
#   inflating: code-samples/Clone913.java
#   inflating: code-samples/Clone915.java
#   inflating: code-samples/Clone917.java
#   inflating: code-samples/Clone922.java
#   inflating: code-samples/Clone924.java
#   inflating: code-samples/Clone925.java
#   inflating: code-samples/Clone926.java
#   inflating: code-samples/Clone937.java
#   inflating: code-samples/Clone938.java
#   inflating: code-samples/Clone939.java
#   inflating: code-samples/Clone940.java
#   inflating: code-samples/Clone941.java
#   inflating: code-samples/Clone944.java
#   inflating: code-samples/Clone948.java
#   inflating: code-samples/Clone949.java
#   inflating: code-samples/Clone951.java
#   inflating: code-samples/Clone960.java
#   inflating: code-samples/Clone963.java
#   inflating: code-samples/Clone964.java
#   inflating: code-samples/Clone966.java
#   inflating: code-samples/Clone973.java
#   inflating: code-samples/Clone974.java
#   inflating: code-samples/Clone975.java
#   inflating: code-samples/Clone976.java
#   inflating: code-samples/Clone977.java
#   inflating: code-samples/Clone978.java
#   inflating: code-samples/Clone98.java
#   inflating: code-samples/Clone983.java
#   inflating: code-samples/Clone987.java
#   inflating: code-samples/Clone988.java
#   inflating: code-samples/Clone992.java
#   inflating: code-samples/Clone995.java
#   inflating: code-samples/Clone996.java
#   inflating: code-samples/Clone997.java
#   inflating: code-samples/code-samples.code-workspace

# %% [markdown]
# # Get Mutated Code (MethodDef)

# %%
import asts  # Assuming you have imported the required module
import csv
def add_escape_before_double_quotes(input_string):
    return input_string.replace('"', '\\"')

def get_substrings(original_string, positions):
    substrings = []

    for start, end in sorted(positions, key=lambda x: x[0]):  # Sort positions by start
        start = start - 2
        end = end -2
        if start < 0 or end < start or end > len(original_string):
            # Handle invalid input for each position
            continue

        substring = original_string[start:end]
        substrings.append(substring)

    return substrings


def get_closest_substrings(source_ranges, positions):

        closest_node = None
        closest_distance = float('inf')  # Initialize with a large value
        closest_nodes = []

        for start, end in positions:
            closest_node = None
            closest_distance = float('inf')  # Initialize with a large value
            closest_start_distance = float('inf')
            closest_end_distance = float('inf')

            for node, (node_start, node_end) in source_ranges:
              start_distance = abs(start - node_start[1])
              end_distance = abs(end - node_end[1])
              # print(start_distance)
              # print(end_distance)

              if (start_distance + end_distance)  <= (closest_start_distance + closest_end_distance):
                  closest_start_distance = start_distance
                  closest_end_distance = end_distance

                  closest_node = node
            if closest_node is not None and closest_node not in closest_nodes:
                  closest_nodes.append(closest_node.source_text)
            return closest_nodes



def remove_substrings(original_string, substrings):
    result = original_string

    for substring in substrings:
        result = result.replace(substring, '', 1)  # Remove the first occurrence of the substring

    return result

def getMutatedCode(filename, linenum, originalcode, positions):

    muterror_filename = 'muterrorreport.csv'
    successmutation_filename = 'successfulmutationstatusreport.csv'

    with open(muterror_filename,'a') as error_file, open(successmutation_filename, 'a') as success_file:
        csvwriter = csv.writer(error_file)
        csvwritersuccess = csv.writer(success_file)

        # Determine the number of spaces at the beginning of the original code
        leading_spaces = len(originalcode) - len(originalcode.lstrip())

        # Filter positions based on end value and adjust start and end positions
        positions = [
            (max(1, start - leading_spaces + 1), end - leading_spaces + 1)
            for start, end in positions if end > leading_spaces
        ]
        print(positions)

        # print('original code:', originalcode)
        try:
            root = asts.AST.from_string(
                originalcode,
                language=asts.ASTLanguage.Java,
                    deepest= True
            )
            source_ranges = root.ast_source_ranges()
            print(source_ranges)

            for node, (node_start, node_end) in source_ranges:
                source_text = originalcode[node_start[0] - 1:node_end[0]]
                print(f"Source Text: {node.source_text}, Start: {node_start[1]}, End: {node_end[1]}")
        except:
          print('issue with ast creation from input string')
          error_items = ['issue with ast creation from input string',node, '', filename, linenum, '']
          all_errors = ', '.join(str(item) for item in error_items)
          csvwriter = csv.writer(error_file)
          return 'error'

          # csvwriter.writerow('issue with ast creation from input string')
        try:
            for a in root.traverse():
                if isinstance(a, asts.types.JavaErrorTree) or isinstance(a, asts.types.JavaErrorVariationPointTree):
                    # founderrornode = True
                    print('original code has errortree')
                    # make special cut
                    # Get specified substrings
                    substrings_to_remove = get_closest_substrings(source_ranges, positions)
                    # Remove specified substrings
                    specialmutation = remove_substrings(root.source_text, substrings_to_remove)
                    success_items = ['special replace success', '-','-', filename, linenum, specialmutation]
                    all_success = ', '.join(str(item) for item in success_items)
                    csvwritersuccess.writerow([all_success])
                    # return mutataion
                    print('specialmutation',specialmutation)
                    return specialmutation

        except Exception as e:
            print('issue with special mutation', e)

            error_items = ['issue with special mutataion',node, '', filename, linenum, e]
            all_errors = ', '.join(str(item) for item in error_items)
            csvwriter = csv.writer(error_file)
            return 'error'

        # print(source_ranges)
        closest_node = None
        closest_distance = float('inf')  # Initialize with a large value
        closest_nodes = []

        for start, end in positions:
            closest_node = None
            closest_distance = float('inf')  # Initialize with a large value
            closest_start_distance = float('inf')
            closest_end_distance = float('inf')

            for node, (node_start, node_end) in source_ranges:
              start_distance = abs(start - node_start[1])
              end_distance = abs(end - node_end[1])
              # print(start_distance)
              # print(end_distance)

              if (start_distance + end_distance)  <= (closest_start_distance + closest_end_distance):
                  closest_start_distance = start_distance
                  closest_end_distance = end_distance

                  closest_node = node
            if closest_node is not None and closest_node not in closest_nodes:
                  closest_nodes.append(closest_node)
            # print(f"Closest node for start {start} and end {end}: {closest_node.source_text}")


        # print("Array of closest nodes:", closest_nodes)
        mutationcounter = 0
        for node in closest_nodes:
          print(node.ast_at_point)
          label_Selection = node.source_text
          print('labelselection', label_Selection)

          if node != root:
            itsparent = node.parent(root)
            try:
                newroot = asts.AST.cut(root, node)
                print('modified code:', newroot.source_text)
                # print('cut ok')
                root = newroot
                success_items = ['node cut success', node, itsparent, filename, linenum, label_Selection]
                all_success = ', '.join(str(item) for item in success_items)
                csvwritersuccess.writerow([all_success])
                mutationcounter = mutationcounter + 1
                continue

            except:
                # print('caught exception: cannot mutate the selected node')
                      print('cannot cut node')
                      error_items = ['cannot cut node',node, itsparent, filename, linenum, label_Selection]
                      all_errors = ', '.join(str(item) for item in error_items)
                      csvwriter = csv.writer(error_file)
            # try:
            #         newroot = asts.AST.replace(root, node,'')
            #         # print('modified code:', newroot.source_text)
            #         print('node replaced with space')
            #         root = newroot
            #         return newroot.source_text
            # except:


                      # print('cannot replace node with space')
            itsparent = node.parent(root)
                      # print('its parent: ',itsparent.source_text, itsparent.ast_source_ranges()[0][0])
                      # check if node is a return statement
            if isinstance(node, asts.types.JavaReturnStatement) or isinstance(node, asts.types.JavaReturnStatement0) or isinstance(node, asts.types.JavaReturnStatement1):
                        #remove the return variable from ast
                try:
                  returnstmtidentifier = node.children[0]
                        # print(returnstmtidentifier)
                  newroot = asts.AST.cut(root, returnstmtidentifier)
                        # print('modified code:', newroot.source_text)
                  root = newroot
                  success_items = ['return stmt mutation success', node, itsparent, filename, linenum, label_Selection]
                  all_success = ', '.join(str(item) for item in success_items)
                  csvwritersuccess.writerow([all_success])
                  mutationcounter = mutationcounter + 1
                  continue

                except:
                      error_items = ['cannot mutate return statement',node, itsparent, filename, linenum, label_Selection]
                      all_errors = ', '.join(str(item) for item in error_items)
                      csvwriter = csv.writer(error_file)



                      # check the parent is a binary expression
            elif isinstance(itsparent, asts.types.JavaBinaryExpression):
                   try:
                        rhs = itsparent.children[-1]
                        lhs = itsparent.children[-3]
                        # print(lhs.source_text)
                        # print()
                        if (label_Selection in lhs.source_text) or (label_Selection == lhs.source_text):
                          newroot = asts.AST.replace(root, itsparent, rhs)
                          # print('modified code:', newroot.source_text)
                          root = newroot

                        else:
                          newroot = asts.AST.replace(root, itsparent, lhs)
                          # print('modified code:', newroot.source_text)
                          root = newroot
                        success_items = ['parent binary expression mutation success', node, itsparent, filename, linenum, label_Selection]
                        all_success = ', '.join(str(item) for item in success_items)
                        csvwritersuccess.writerow([all_success])
                        mutationcounter = mutationcounter + 1
                        continue
                   except:
                        error_items = ['cannot mutate parent binary expr',node, itsparent, filename, linenum, label_Selection]
                        all_errors = ', '.join(str(item) for item in error_items)
                        csvwriter = csv.writer(error_file)

            elif isinstance(itsparent, asts.types.JavaArgumentList) or isinstance(itsparent, asts.types.JavaArgumentList0) or isinstance(itsparent, asts.types.JavaArgumentList1):
                          # print('Ifstatement')
                          # replace with empty string
                    try:
                          for child in itsparent.children:
                              newroot = asts.AST.cut(root, child)
                              # print('modified code:', newroot.source_text)
                              root = newroot
                          success_items = ['arg list mutation success', node, itsparent, filename, linenum, label_Selection]
                          all_success = ', '.join(str(item) for item in success_items)
                          csvwritersuccess.writerow([all_success])
                          mutationcounter = mutationcounter + 1
                          continue
                    except:
                        error_items = ['cannot mutate arg list',node, itsparent, filename, linenum, label_Selection]
                        all_errors = ', '.join(str(item) for item in error_items)
                        csvwriter = csv.writer(error_file)

            # elif isinstance(node, asts.types.JavaTypeIdentifier):
            #               newroot = asts.AST.replace(root, node,'')
            #               root = newroot

            else:

                          print('Node is not processed:',node, itsparent, filename, linenum, label_Selection )
                          # with open(muterror_filename,'a') as error_file:
                          error_items = ['no mutation worked',node, itsparent, filename, linenum, label_Selection]
                          all_errors = ', '.join(str(item) for item in error_items)
                          csvwriter = csv.writer(error_file)
                          csvwriter.writerow([all_errors])
                          return 'remove'

                          # replace with empty string
                          try:
                              if root != itsparent:

                                newroot = asts.AST.replace(root, itsparent,'')

                                print(newroot.ast_source_ranges())
                                print('modified code:', newroot.source_text)
                                root = newroot
                          except Exception as e:
                              print("Error while processing AST:")
                              with open(muterror_filename,'a') as error_file:
                                  error_items = ['parent replacement failed',node, itsparent, filename, linenum, label_Selection]
                                  all_errors = ', '.join(str(item) for item in error_items)
                                  csvwriter = csv.writer(error_file)
                                  csvwriter.writerow([all_errors])
                              return 'asterror'


          else:
            print ('root and node are the same')
            with open(muterror_filename,'a') as error_file:
                        error_items = ['closest node is root',node, '-', filename, linenum, label_Selection]
                        all_errors = ', '.join(str(item) for item in error_items)
                        csvwriter = csv.writer(error_file)
                        csvwriter.writerow([all_errors])
            return 'remove'


        newroot = root
        try:
            print(newroot.source_text)
            success_items = ['mutation success', node, itsparent, filename, linenum, label_Selection]
            all_success = ', '.join(str(item) for item in success_items)
            csvwritersuccess.writerow([all_success])
            return newroot.source_text
        except:
              # with open(muterror_filename,'a') as error_file:
              error_items = ['invalid AST after mutation',node, '-', filename, linenum, label_Selection]
              all_errors = ', '.join(str(item) for item in error_items)
              csvwriter = csv.writer(error_file)
              csvwriter.writerow([all_errors])
              return 'remove'

# Example usage
originalcode = "    if (s == null || size <= s.length ()) return s;"
positions = [(5, 18)]  # List of input start and end positions

# originalcode = "    int before = (len - text.length ()) / 2;"
# positions = [(1, 4),(4,44)]  # List of input start and end positions

# originalcode = "    try(File in = new File ())"
# positions = [(5,8)]

# print("Adjusted positions:", positions)

# mutated_code = getMutatedCode('DummyFile.java',1,originalcode, positions)
# print('Mutated Code:', mutated_code)

# %% [markdown]
# # Process Resolved Labels CSV and get mutated code
#
#
# ---

# %%
process_csv_file_name = "lxresolution_280_authorlabels.csv"

import csv
import linecache
# import asts

class LineData:
    def __init__(self, positions, codes, labelvalues):
        # self.mutop = mutop
        # self.modifiedcode = modifiedcode
        self.positions = positions
        self.codes = codes
        self.labelvalues = labelvalues

class MutatedLineData:
    def __init__(self, mutatedcode,mutop):

        self.mutatedcode = mutatedcode
        self.mutop = mutop

def find_lonely_brackets(java_code):
    stack = []
    unmatched_brackets = []

    # Define bracket pairs
    bracket_pairs = {')': '(', '}': '{', ']': '['}

    for i, char in enumerate(java_code):
        if char in '([{':
            stack.append((char, i))
        elif char in ')]}':
            if not stack:
                unmatched_brackets.append((char, i))
            else:
                top_char, _ = stack.pop()
                if top_char != bracket_pairs[char]:
                    unmatched_brackets.append((top_char, i))

    # Any remaining characters in the stack are unmatched
    while stack:
        char, i = stack.pop()
        unmatched_brackets.append((char, i))

    return unmatched_brackets

def is_whole_line_selected(code, start, end):
    # selected_text = code[start-1:end+1]
    # return selected_text == code and start==1
    trimmedcode = code.lstrip().rstrip("\n")
    labeledcode = code[start:end]
    # print('labeled code', code, labeledcode)
    trimmedlabelcode = labeledcode.lstrip()
    # print(trimmedcode == trimmedlabelcode)
    return trimmedcode == trimmedlabelcode

def process_csv(filename, value, lower_range_wise, upper_range_wise, concrete ):
    with open(filename, 'r', encoding="utf-8-sig") as csv_file:
        csv_reader = csv.DictReader(csv_file)
        current_filename = None
        current_line = None
        char_positions_for_line = []
        positions = []
        line_data_dict = {}

        for row in csv_reader:
            print(row)
            filename = row['FileName']
            line_start = int(row['LineStart'])
            char_start = int(row['CharStart'])
            char_end = int(row['CharEnd'])
            code = row['Code']
            labelvalue = row['LabelValue']

            condition = False
            if lower_range_wise == False and upper_range_wise == False:
                if float(labelvalue) == value:
                  condition = True
                else:
                  condition = False
            elif lower_range_wise == True and upper_range_wise == False:
              if concrete == False:
                if float(labelvalue) <= value:
                  condition = True
                else:
                  condition = False
              else:
                if float(labelvalue) == value or float(labelvalue) == value-1:
                  condition = True
                else:
                  condition = False
            elif lower_range_wise == False and upper_range_wise == True :
              if concrete == False:
                if float(labelvalue) >= value:
                  condition = True
                else:
                  condition = False
              else:
                 if float(labelvalue) == value or float(labelvalue) == value+1:
                  condition = True
                 else:
                  condition = False

            elif lower_range_wise == True and upper_range_wise == True:
                if float(labelvalue) == value:
                  condition = True
                else:
                  condition = False

            if condition:

                char_positions_for_line = []
                positions = []
                codes = []
                labelvalues = []
                positions.append(char_start)
                positions.append(char_end)
                line_data = line_data_dict.get((filename, line_start))
                if line_data:
                    line_data.positions.append(positions)
                    line_data.codes.append(code)
                    line_data.labelvalues.append(labelvalue)
                else:
                    char_positions_for_line.append(positions)
                    codes.append(code)
                    labelvalues.append(labelvalue)
                    line_data_dict[(filename, line_start)] = LineData(char_positions_for_line, codes, labelvalues)


    return line_data_dict


# read resolved labels data and perform mutataions and get the linewise mutations


# line_data_dict = process_csv('resolvedauthorlabels.csv',2.0)

# case 1: Value-based mutation. Remove core sim (2) or core diff (-2). Removes lines with label value set to value = 2 or -2
value = -2
lower_range_wise = False
upper_range_wise = False
concrete = False  #dont care


# case 2: Value-based mutation. Remove any non-core sim (1) or core sim (2). Removes lines with label value = 1 and one value above it e.g. if value is 1, will consider value 2 ones for removal also.
# value = 1
# lower_range_wise = False
# upper_range_wise = True
# concrete = True

# case 3: Value-based mutation. Remove any non-core diff (-1) or core diff (-2). Removes lines with label value = -1 and one value below it e.g. if value is -1, will consider value -2 ones for removal also.
# value = -1
# lower_range_wise = True
# upper_range_wise = False
# concrete = True


# case 4: Range-based mutation. Remove core sim if value=1.5 or any sim if value=0.5. Removes lines with label value and all values above it e.g. if value is 1.5, will consider value 1.6 etc. for removal also till 2.
# value can be 0.5 or 1.5 to select all core and noncore similarities or just core similarities respectively
# value = 0.5
# lower_range_wise = False
# upper_range_wise = True
# concrete = False

# case 5: Range-based mutation. Remove core diff if value= -1.5 or any diff if value= -0.5. Removes lines with input label value and all values below it e.g. if value is -0.5, will consider value -1.5 etc. for removal also till -2
# # value can be -0.5 or -1.5 to select all core and noncore differences or just core differences respectively
# value = -1.5
# lower_range_wise = True
# upper_range_wise = False
# concrete = False

# line_data_dict = process_csv('resolved_280_authorlabels.csv',value, lower_range_wise, upper_range_wise, concrete)
line_data_dict = process_csv(process_csv_file_name, value, lower_range_wise, upper_range_wise, concrete)
print(line_data_dict)
# for (filename, line_start), line_data in line_data_dict.items():
    # print(f"Filename: {filename}, Line: {line_start}")
    # print(f"Positions: {line_data.positions} codes: {line_data.codes} labelvalues: {line_data.labelvalues}")
    # print()  # Print a blank line between entries

# for each line get mutated code
mutated_line_data_dict = {}

for (filename, line_start), line_data in line_data_dict.items():
    # print(f"Filename: {filename}, Line: {line_start}")
    line = linecache.getline('code-samples/'+ filename, line_start+1)
    print("Line", line_start, ":", line)
    # Determine the number of spaces at the beginning of the original code
    leading_spaces = len(line) - len(line.lstrip())

    # Filter positions based on end value
    # if end position occurs in leading whitespace we dont need that position
    positions = [
        (start, end)
        for start, end in line_data.positions if end > leading_spaces
    ]
    line_data.positions = positions

    print("Adjusted positions:", positions, len(positions))

    if (len(line_data.positions) == 1):
                # check if position covers whole line, set remove as mutop else mod

                if(is_whole_line_selected(line, line_data.positions[0][0], line_data.positions[0][1])):
                  # mutated_line_data_dict[(filename, line_start+1)] = MutatedLineData('',"remove")
                  # print("Line ", line_start, "removed")
                      unmatched_brackets = find_lonely_brackets(line)
                      brackets_string = ''
                      if unmatched_brackets:
                          for bracket, position in unmatched_brackets:
                              # print(f"Unmatched Bracket '{bracket}' at position {position}")
                              brackets_string = brackets_string + bracket
                          mutated_code = brackets_string
                          mutated_line_data_dict[(filename, line_start + 1)] = MutatedLineData(mutated_code, "mutate")
                      else:
                          mutated_line_data_dict[(filename, line_start+1)] = MutatedLineData('',"remove")
                          print("Line ", line_start, "removed")

                else:
                  print("Line ", line_start, "mutated to ")
                  mutated_code = getMutatedCode(filename, line_start, line, line_data.positions)
                  if(mutated_code == "remove"):
                      unmatched_brackets = find_lonely_brackets(mutated_code)
                      brackets_string = ''
                      if unmatched_brackets:
                          for bracket, position in unmatched_brackets:
                              # print(f"Unmatched Bracket '{bracket}' at position {position}")
                              brackets_string.append(bracket)
                          mutated_code = brackets_string
                          mutated_line_data_dict[(filename, line_start + 1)] = MutatedLineData(mutated_code, "mutate")
                      else:
                          mutated_line_data_dict[(filename, line_start+1)] = MutatedLineData('',"remove")
                          print("Line ", line_start, "removed")

                  else:
                       mutated_line_data_dict[(filename, line_start + 1)] = MutatedLineData(mutated_code, "mutate")
    elif (len(line_data.positions) > 1):
        print("Line ", line_start, "mutated to ")
        mutated_code = getMutatedCode(filename, line_start, line, line_data.positions)
        # mutated_line_data_dict[(filename, line_start + 1)] = MutatedLineData(mutated_code, "mutate")
        if(mutated_code == "remove"):
                      unmatched_brackets = find_lonely_brackets(mutated_code)
                      brackets_string = ''
                      if unmatched_brackets:
                          for bracket, position in unmatched_brackets:
                              # print(f"Unmatched Bracket '{bracket}' at position {position}")
                              brackets_string.append(bracket)
                          mutated_code = brackets_string
                          mutated_line_data_dict[(filename, line_start + 1)] = MutatedLineData(mutated_code, "mutate")
                      else:
                          mutated_line_data_dict[(filename, line_start+1)] = MutatedLineData('',"remove")
                          print("Line ", line_start, "removed")

        else:
                       mutated_line_data_dict[(filename, line_start + 1)] = MutatedLineData(mutated_code, "mutate")



# build a new mutated file
for (filename, line_start), line_data in mutated_line_data_dict.items():
    print(filename,line_start, line_data.mutatedcode, line_data.mutop)

# original_filename = filename
# mutated_filename = filename + 'mutated.java'

# Read the original file and create the mutated file
# with open(original_filename, 'r') as original_file, open(mutated_filename, 'w') as mutated_file:
#     for line_number, line in enumerate(original_file, start=1):
#         # Check if there's mutated data for this line
#         mutated_line_data = mutated_line_data_dict.get((original_filename, line_number))

#         if mutated_line_data:
#             # Replace the line with mutated data
#             mutated_file.write(mutated_line_data.mutatedcode + '\n')
#         else:
#             # Copy the original line as-is
#             mutated_file.write(line)
# Out:
# Streaming output truncated to the last 5000 lines.
# Line  94 removed
# Line 95 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 9 :     Class unsafeClass = Class.forName ("sun.misc.Unsafe");
#
# Adjusted positions: [(1, 58)] 1
# Line  9 removed
# Line 10 :     Field f = unsafeClass.getDeclaredField ("theUnsafe");
#
# Adjusted positions: [(1, 57)] 1
# Line  10 removed
# Line 11 :     f.setAccessible (true);
#
# Adjusted positions: [(1, 27)] 1
# Line  11 removed
# Line 12 :     Unsafe unsafe = (Unsafe) f.get (null);
#
# Adjusted positions: [(1, 42)] 1
# Line  12 removed
# Line 13 :     System.out.print ("4..3..2..1...");
#
# Adjusted positions: [] 0
# Line 14 :     try {
#
# Adjusted positions: [(1, 9)] 1
# Line 15 :         for (;;) unsafe.allocateMemory (1024 * 1024);
#
# Adjusted positions: [(1, 53)] 1
# Line  15 removed
# Line 16 :     } catch (Error e) {
#
# Adjusted positions: [(1, 23)] 1
# Line 17 :         System.out.println ("Boom :)");
#
# Adjusted positions: [(1, 39)] 1
# Line 18 :         e.printStackTrace ();
#
# Adjusted positions: [(1, 29)] 1
# Line  18 removed
# Line 19 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 23 :     while (makeMore) {
#
# Adjusted positions: [(1, 22)] 1
# Line 24 :         new Leakee (0).check ();
#
# Adjusted positions: [(1, 32)] 1
# Line  24 removed
# Line 25 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 26 :     while (true) {
#
# Adjusted positions: [(1, 18)] 1
# Line 27 :         Thread.sleep (1000);
#
# Adjusted positions: [(1, 28)] 1
# Line  27 removed
# Line 28 :         System.out.println ("memory=" + Runtime.getRuntime ().freeMemory () + " / " + Runtime.getRuntime ().totalMemory ());
#
# Adjusted positions: [(1, 124)] 1
# Line  28 removed
# Line 29 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 9 :     System.out.println ("Enter name");
#
# Adjusted positions: [] 0
# Line 10 :     Scanner kb = new Scanner (System.in);
#
# Adjusted positions: [(1, 41)] 1
# Line  10 removed
# Line 11 :     String text = kb.next ();
#
# Adjusted positions: [(1, 29)] 1
# Line  11 removed
# Line 12 :     if (null == text || text.isEmpty ()) {
#
# Adjusted positions: [(1, 42)] 1
# Line 13 :         System.out.println ("Text empty");
#
# Adjusted positions: [(1, 42)] 1
# Line  13 removed
# Line 14 :     } else if (text.charAt (0) == (text.toUpperCase ().charAt (0))) {
#
# Adjusted positions: [(1, 69)] 1
# Line 15 :         System.out.println ("First letter in word " + text + " is upper case");
#
# Adjusted positions: [(1, 79)] 1
# Line  15 removed
# Line 16 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 20 :     String str1 = "";
#
# Adjusted positions: [(1, 21)] 1
# Line  20 removed
# Line 21 :     String str2 = null;
#
# Adjusted positions: [(1, 23)] 1
# Line  21 removed
# Line 22 :     String str3 = "Starts with upper case";
#
# Adjusted positions: [(1, 43)] 1
# Line  22 removed
# Line 23 :     String str4 = "starts with lower case";
#
# Adjusted positions: [(1, 43)] 1
# Line  23 removed
# Line 24 :     System.out.println (startWithUpperCase (str1));
#
# Adjusted positions: [(1, 51)] 1
# Line  24 removed
# Line 25 :     System.out.println (startWithUpperCase (str2));
#
# Adjusted positions: [(1, 51)] 1
# Line  25 removed
# Line 26 :     System.out.println (startWithUpperCase (str3));
#
# Adjusted positions: [(1, 51)] 1
# Line  26 removed
# Line 27 :     System.out.println (startWithUpperCase (str4));
#
# Adjusted positions: [(1, 51)] 1
# Line  27 removed
# Line 9 :     target.mouseReleased (e);
#
# Adjusted positions: [(4, 29)] 1
# Line  9 removed
# Line 10 :     if (pressed != null) {
#
# Adjusted positions: [] 0
# Line 11 :         if (getDragDistance (e) < MAX_CLICK_DISTANCE) {
#
# Adjusted positions: [(1, 55)] 1
# Line 12 :             MouseEvent clickEvent = new MouseEvent ((Component) pressed.getSource (), MouseEvent.MOUSE_CLICKED, e.getWhen (), pressed.getModifiers (), pressed.getX (), pressed.getY (), pressed.getXOnScreen (), pressed.getYOnScreen (), pressed.getClickCount (), pressed.isPopupTrigger (), pressed.getButton ());
#
# Adjusted positions: [(1, 310)] 1
# Line  12 removed
# Line 13 :             target.mouseClicked (clickEvent);
#
# Adjusted positions: [(1, 45)] 1
# Line  13 removed
# Line 14 :         }
#
# Adjusted positions: [(1, 9)] 1
# Line 22 :     } else if (dragLocation != null) {
#
# Adjusted positions: [(5, 38)] 1
# Line  22 mutated to
# [(2, 35)]
# [(<asts.types.JavaProgram 0x5a1b>, ((1, 1), (2, 1))), (<asts.types.JavaErrorVariationPointTree 0x5a1c>, ((1, 1), (1, 11))), (<asts.types.JavaErrorTree 0x5a1e>, ((1, 5), (1, 11))), (<asts.types.JavaCloseBrace 0x5a1f>, ((1, 5), (1, 6))), (<asts.types.JavaInnerWhitespace 0x5a20>, ((1, 6), (1, 7))), (<asts.types.JavaElse 0x5a21>, ((1, 7), (1, 11))), (<asts.types.JavaIfStatement1 0x5a22>, ((1, 11), (2, 1))), (<asts.types.JavaParenthesizedExpression 0x5a23>, ((1, 14), (1, 37))), (<asts.types.JavaBinaryExpression 0x5a24>, ((1, 16), (1, 36))), (<asts.types.JavaIdentifier 0x5a25>, ((1, 16), (1, 28))), (<asts.types.JavaNotEqual 0x5a26>, ((1, 28), (1, 31))), (<asts.types.JavaNullLiteral 0x5a27>, ((1, 31), (1, 36))), (<asts.types.JavaBlock 0x5a28>, ((1, 37), (1, 40))), (<asts.types.JavaInnerWhitespace 0x5a29>, ((1, 39), (1, 39)))]
# Source Text:     } else if (dragLocation != null) {}
# , Start: 1, End: 1
# Source Text: } else, Start: 1, End: 11
# Source Text: } else, Start: 5, End: 11
# Source Text: }, Start: 5, End: 6
# Source Text:  , Start: 6, End: 7
# Source Text: else, Start: 7, End: 11
# Source Text: if (dragLocation != null) {}, Start: 11, End: 1
# Source Text: (dragLocation != null), Start: 14, End: 37
# Source Text: dragLocation != null, Start: 16, End: 36
# Source Text: dragLocation, Start: 16, End: 28
# Source Text: !=, Start: 28, End: 31
# Source Text: null, Start: 31, End: 36
# Source Text: {}, Start: 37, End: 40
# Source Text: , Start: 39, End: 39
# original code has errortree
# specialmutation     } else if  {}
#
# Line 23 :     } else {
#
# Adjusted positions: [(1, 12)] 1
# Line 24 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 25 :     pressLocation = null;
#
# Adjusted positions: [(1, 25)] 1
# Line  25 removed
# Line 26 :     dragLocation = null;
#
# Adjusted positions: [(1, 24)] 1
# Line  26 removed
# Line 9 :     int emptyCycleCounter = 0;
#
# Adjusted positions: [] 0
# Line 10 :     while (true) {
#
# Adjusted positions: [(1, 18)] 1
# Line 11 :         int i = counter.get ();
#
# Adjusted positions: [(1, 31)] 1
# Line  11 removed
# Line 12 :         if (i > MAX_COUNTER) {
#
# Adjusted positions: [(1, 30)] 1
# Line 13 :             break;
#
# Adjusted positions: [(1, 18)] 1
# Line  13 removed
# Line 14 :         }
#
# Adjusted positions: [(1, 9)] 1
# Line 15 :         if (i % 2 == (odd ? 1 : 0)) {
#
# Adjusted positions: [(1, 37)] 1
# Line 16 :             System.out.println (i + (odd ? " odd" : " even"));
#
# Adjusted positions: [(1, 62)] 1
# Line  16 removed
# Line 17 :             counter.incrementAndGet ();
#
# Adjusted positions: [(1, 39)] 1
# Line  17 removed
# Line 18 :         } else {
#
# Adjusted positions: [(1, 16)] 1
# Line 19 :             emptyCycleCounter ++;
#
# Adjusted positions: [(1, 33)] 1
# Line  19 removed
# Line 20 :             Thread.yield ();
#
# Adjusted positions: [(1, 28)] 1
# Line  20 removed
# Line 21 :         }
#
# Adjusted positions: [(1, 9)] 1
# Line 22 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 23 :     System.out.println ("Finished" + (odd ? " odd" : " even") + " with " + emptyCycleCounter + " empty cycles.");
#
# Adjusted positions: [] 0
# Line 27 :     for (int i = 1;
#
# Adjusted positions: [(1, 19)] 1
# Line 28 :     i < 10; i += 2) {
#
# Adjusted positions: [(1, 21)] 1
# Line 29 :         synchronized (o) {
#
# Adjusted positions: [(1, 26)] 1
# Line 30 :             try {
#
# Adjusted positions: [(1, 17)] 1
# Line 31 :                 while (! turn) {
#
# Adjusted positions: [(1, 32)] 1
# Line 32 :                     o.wait ();
#
# Adjusted positions: [(1, 30)] 1
# Line  32 removed
# Line 33 :                 }
#
# Adjusted positions: [(1, 17)] 1
# Line 34 :             } catch (InterruptedException ie) {
#
# Adjusted positions: [(1, 47)] 1
# Line 35 :                 ie.printStackTrace ();
#
# Adjusted positions: [(1, 38)] 1
# Line  35 removed
# Line 36 :             } finally {
#
# Adjusted positions: [(1, 23)] 1
# Line 37 :                 System.out.println (i);
#
# Adjusted positions: [(1, 39)] 1
# Line  37 removed
# Line 38 :                 turn = ! turn;
#
# Adjusted positions: [(1, 30)] 1
# Line  38 removed
# Line 39 :                 o.notifyAll ();
#
# Adjusted positions: [(1, 31)] 1
# Line  39 removed
# Line 40 :             }
#
# Adjusted positions: [(1, 13)] 1
# Line 41 :         }
#
# Adjusted positions: [(1, 9)] 1
# Line 42 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 17 :         Runnable worldTask = new Runnable () {
#
# Adjusted positions: [(1, 46)] 1
# Line 18 :             @Override
#
# Adjusted positions: [(1, 21)] 1
# Line  18 removed
# Line 19 :             public void run () {
#
# Adjusted positions: [(1, 32)] 1
# Line 20 :                 new ThreadSeq ().printWorld ();
#
# Adjusted positions: [(1, 47)] 1
# Line  20 removed
# Line 21 :             }}
#
# Adjusted positions: [(1, 14)] 1
# Line 22 :         ;
#
# Adjusted positions: [(1, 9)] 1
# Line  22 removed
# Line 24 :         Thread t2 = new Thread (worldTask);
#
# Adjusted positions: [(8, 43)] 1
# Line  24 removed
# Line 9 :     keyPress (VK_ALT);
#
# Adjusted positions: [(14, 20)] 1
# Line  9 mutated to
# [(11, 17)]
# [(<asts.types.JavaExpressionStatement 0x5a2b>, ((1, 1), (1, 19))), (<asts.types.JavaMethodInvocation0 0x5a2c>, ((1, 1), (1, 18))), (<asts.types.JavaIdentifier 0x5a2d>, ((1, 1), (1, 9))), (<asts.types.JavaArgumentList0 0x5a2e>, ((1, 9), (1, 18))), (<asts.types.JavaIdentifier 0x5a2f>, ((1, 11), (1, 17)))]
# Source Text: keyPress (VK_ALT);, Start: 1, End: 19
# Source Text: keyPress (VK_ALT), Start: 1, End: 18
# Source Text: keyPress, Start: 1, End: 9
# Source Text: (VK_ALT), Start: 9, End: 18
# Source Text: VK_ALT, Start: 11, End: 17
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a2f>>
# labelselection VK_ALT
# modified code: keyPress ();
# keyPress ();
# Line 10 :     keyPress (VK_NUMPAD0);
#
# Adjusted positions: [(14, 24)] 1
# Line  10 mutated to
# [(11, 21)]
# [(<asts.types.JavaExpressionStatement 0x5a34>, ((1, 1), (1, 23))), (<asts.types.JavaMethodInvocation0 0x5a35>, ((1, 1), (1, 22))), (<asts.types.JavaIdentifier 0x5a36>, ((1, 1), (1, 9))), (<asts.types.JavaArgumentList0 0x5a37>, ((1, 9), (1, 22))), (<asts.types.JavaIdentifier 0x5a38>, ((1, 11), (1, 21)))]
# Source Text: keyPress (VK_NUMPAD0);, Start: 1, End: 23
# Source Text: keyPress (VK_NUMPAD0), Start: 1, End: 22
# Source Text: keyPress, Start: 1, End: 9
# Source Text: (VK_NUMPAD0), Start: 9, End: 22
# Source Text: VK_NUMPAD0, Start: 11, End: 21
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a38>>
# labelselection VK_NUMPAD0
# modified code: keyPress ();
# keyPress ();
# Line 11 :     keyRelease (VK_NUMPAD0);
#
# Adjusted positions: [(16, 26)] 1
# Line  11 mutated to
# [(13, 23)]
# [(<asts.types.JavaExpressionStatement 0x5a3d>, ((1, 1), (1, 25))), (<asts.types.JavaMethodInvocation0 0x5a3e>, ((1, 1), (1, 24))), (<asts.types.JavaIdentifier 0x5a3f>, ((1, 1), (1, 11))), (<asts.types.JavaArgumentList0 0x5a40>, ((1, 11), (1, 24))), (<asts.types.JavaIdentifier 0x5a41>, ((1, 13), (1, 23)))]
# Source Text: keyRelease (VK_NUMPAD0);, Start: 1, End: 25
# Source Text: keyRelease (VK_NUMPAD0), Start: 1, End: 24
# Source Text: keyRelease, Start: 1, End: 11
# Source Text: (VK_NUMPAD0), Start: 11, End: 24
# Source Text: VK_NUMPAD0, Start: 13, End: 23
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a41>>
# labelselection VK_NUMPAD0
# modified code: keyRelease ();
# keyRelease ();
# Line 12 :     String altCode = Integer.toString (c);
#
# Adjusted positions: [(1, 42)] 1
# Line  12 removed
# Line 13 :     for (int i = 0;
#
# Adjusted positions: [(1, 19)] 1
# Line 14 :     i < altCode.length (); i ++) {
#
# Adjusted positions: [(1, 34)] 1
# Line 15 :         c = (char) (altCode.charAt (i) + '0');
#
# Adjusted positions: [(1, 46)] 1
# Line  15 removed
# Line 16 :         keyPress (c);
#
# Adjusted positions: [(18, 19)] 1
# Line  16 mutated to
# [(11, 12)]
# [(<asts.types.JavaExpressionStatement 0x5a46>, ((1, 1), (1, 14))), (<asts.types.JavaMethodInvocation0 0x5a47>, ((1, 1), (1, 13))), (<asts.types.JavaIdentifier 0x5a48>, ((1, 1), (1, 9))), (<asts.types.JavaArgumentList0 0x5a49>, ((1, 9), (1, 13))), (<asts.types.JavaIdentifier 0x5a4a>, ((1, 11), (1, 12)))]
# Source Text: keyPress (c);, Start: 1, End: 14
# Source Text: keyPress (c), Start: 1, End: 13
# Source Text: keyPress, Start: 1, End: 9
# Source Text: (c), Start: 9, End: 13
# Source Text: c, Start: 11, End: 12
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a4a>>
# labelselection c
# modified code: keyPress ();
# keyPress ();
# Line 17 :         keyRelease (c);
#
# Adjusted positions: [(20, 21)] 1
# Line  17 mutated to
# [(13, 14)]
# [(<asts.types.JavaExpressionStatement 0x5a4f>, ((1, 1), (1, 16))), (<asts.types.JavaMethodInvocation0 0x5a50>, ((1, 1), (1, 15))), (<asts.types.JavaIdentifier 0x5a51>, ((1, 1), (1, 11))), (<asts.types.JavaArgumentList0 0x5a52>, ((1, 11), (1, 15))), (<asts.types.JavaIdentifier 0x5a53>, ((1, 13), (1, 14)))]
# Source Text: keyRelease (c);, Start: 1, End: 16
# Source Text: keyRelease (c), Start: 1, End: 15
# Source Text: keyRelease, Start: 1, End: 11
# Source Text: (c), Start: 11, End: 15
# Source Text: c, Start: 13, End: 14
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a53>>
# labelselection c
# modified code: keyRelease ();
# keyRelease ();
# Line 18 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 19 :     keyRelease (VK_ALT);
#
# Adjusted positions: [(16, 22)] 1
# Line  19 mutated to
# [(13, 19)]
# [(<asts.types.JavaExpressionStatement 0x5a58>, ((1, 1), (1, 21))), (<asts.types.JavaMethodInvocation0 0x5a59>, ((1, 1), (1, 20))), (<asts.types.JavaIdentifier 0x5a5a>, ((1, 1), (1, 11))), (<asts.types.JavaArgumentList0 0x5a5b>, ((1, 11), (1, 20))), (<asts.types.JavaIdentifier 0x5a5c>, ((1, 13), (1, 19)))]
# Source Text: keyRelease (VK_ALT);, Start: 1, End: 21
# Source Text: keyRelease (VK_ALT), Start: 1, End: 20
# Source Text: keyRelease, Start: 1, End: 11
# Source Text: (VK_ALT), Start: 11, End: 20
# Source Text: VK_ALT, Start: 13, End: 19
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a5c>>
# labelselection VK_ALT
# modified code: keyRelease ();
# keyRelease ();
# Line 23 :     Clipboard clipboard = Toolkit.getDefaultToolkit ().getSystemClipboard ();
#
# Adjusted positions: [(1, 77)] 1
# Line  23 removed
# Line 24 :     StringSelection stringSelection = new StringSelection (characters);
#
# Adjusted positions: [(1, 71)] 1
# Line  24 removed
# Line 25 :     clipboard.setContents (stringSelection, clipboardOwner);
#
# Adjusted positions: [(1, 60)] 1
# Line  25 removed
# Line 26 :     robot.keyPress (KeyEvent.VK_CONTROL);
#
# Adjusted positions: [(1, 10), (20, 39)] 2
# Line  26 mutated to
# [(1, 7), (17, 36)]
# [(<asts.types.JavaExpressionStatement 0x5a61>, ((1, 1), (1, 38))), (<asts.types.JavaMethodInvocation2 0x5a62>, ((1, 1), (1, 37))), (<asts.types.JavaIdentifier 0x5a63>, ((1, 1), (1, 6))), (<asts.types.JavaIdentifier 0x5a64>, ((1, 7), (1, 15))), (<asts.types.JavaArgumentList0 0x5a65>, ((1, 15), (1, 37))), (<asts.types.JavaFieldAccess1 0x5a66>, ((1, 17), (1, 36))), (<asts.types.JavaIdentifier 0x5a67>, ((1, 17), (1, 25))), (<asts.types.JavaIdentifier 0x5a68>, ((1, 26), (1, 36)))]
# Source Text: robot.keyPress (KeyEvent.VK_CONTROL);, Start: 1, End: 38
# Source Text: robot.keyPress (KeyEvent.VK_CONTROL), Start: 1, End: 37
# Source Text: robot, Start: 1, End: 6
# Source Text: keyPress, Start: 7, End: 15
# Source Text: (KeyEvent.VK_CONTROL), Start: 15, End: 37
# Source Text: KeyEvent.VK_CONTROL, Start: 17, End: 36
# Source Text: KeyEvent, Start: 17, End: 25
# Source Text: VK_CONTROL, Start: 26, End: 36
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a63>>
# labelselection robot
# modified code: keyPress (KeyEvent.VK_CONTROL);
# <bound method AST.ast_at_point of <asts.types.JavaFieldAccess1 0x5a66>>
# labelselection KeyEvent.VK_CONTROL
# modified code: keyPress ();
# keyPress ();
# Line 27 :     robot.keyPress (KeyEvent.VK_V);
#
# Adjusted positions: [(1, 10), (20, 33)] 2
# Line  27 mutated to
# [(1, 7), (17, 30)]
# [(<asts.types.JavaExpressionStatement 0x5a6f>, ((1, 1), (1, 32))), (<asts.types.JavaMethodInvocation2 0x5a70>, ((1, 1), (1, 31))), (<asts.types.JavaIdentifier 0x5a71>, ((1, 1), (1, 6))), (<asts.types.JavaIdentifier 0x5a72>, ((1, 7), (1, 15))), (<asts.types.JavaArgumentList0 0x5a73>, ((1, 15), (1, 31))), (<asts.types.JavaFieldAccess1 0x5a74>, ((1, 17), (1, 30))), (<asts.types.JavaIdentifier 0x5a75>, ((1, 17), (1, 25))), (<asts.types.JavaIdentifier 0x5a76>, ((1, 26), (1, 30)))]
# Source Text: robot.keyPress (KeyEvent.VK_V);, Start: 1, End: 32
# Source Text: robot.keyPress (KeyEvent.VK_V), Start: 1, End: 31
# Source Text: robot, Start: 1, End: 6
# Source Text: keyPress, Start: 7, End: 15
# Source Text: (KeyEvent.VK_V), Start: 15, End: 31
# Source Text: KeyEvent.VK_V, Start: 17, End: 30
# Source Text: KeyEvent, Start: 17, End: 25
# Source Text: VK_V, Start: 26, End: 30
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a71>>
# labelselection robot
# modified code: keyPress (KeyEvent.VK_V);
# <bound method AST.ast_at_point of <asts.types.JavaFieldAccess1 0x5a74>>
# labelselection KeyEvent.VK_V
# modified code: keyPress ();
# keyPress ();
# Line 28 :     robot.keyRelease (KeyEvent.VK_V);
#
# Adjusted positions: [(1, 10), (22, 35)] 2
# Line  28 mutated to
# [(1, 7), (19, 32)]
# [(<asts.types.JavaExpressionStatement 0x5a7d>, ((1, 1), (1, 34))), (<asts.types.JavaMethodInvocation2 0x5a7e>, ((1, 1), (1, 33))), (<asts.types.JavaIdentifier 0x5a7f>, ((1, 1), (1, 6))), (<asts.types.JavaIdentifier 0x5a80>, ((1, 7), (1, 17))), (<asts.types.JavaArgumentList0 0x5a81>, ((1, 17), (1, 33))), (<asts.types.JavaFieldAccess1 0x5a82>, ((1, 19), (1, 32))), (<asts.types.JavaIdentifier 0x5a83>, ((1, 19), (1, 27))), (<asts.types.JavaIdentifier 0x5a84>, ((1, 28), (1, 32)))]
# Source Text: robot.keyRelease (KeyEvent.VK_V);, Start: 1, End: 34
# Source Text: robot.keyRelease (KeyEvent.VK_V), Start: 1, End: 33
# Source Text: robot, Start: 1, End: 6
# Source Text: keyRelease, Start: 7, End: 17
# Source Text: (KeyEvent.VK_V), Start: 17, End: 33
# Source Text: KeyEvent.VK_V, Start: 19, End: 32
# Source Text: KeyEvent, Start: 19, End: 27
# Source Text: VK_V, Start: 28, End: 32
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a7f>>
# labelselection robot
# modified code: keyRelease (KeyEvent.VK_V);
# <bound method AST.ast_at_point of <asts.types.JavaFieldAccess1 0x5a82>>
# labelselection KeyEvent.VK_V
# modified code: keyRelease ();
# keyRelease ();
# Line 29 :     robot.keyRelease (KeyEvent.VK_CONTROL);
#
# Adjusted positions: [(1, 10), (22, 41)] 2
# Line  29 mutated to
# [(1, 7), (19, 38)]
# [(<asts.types.JavaExpressionStatement 0x5a8b>, ((1, 1), (1, 40))), (<asts.types.JavaMethodInvocation2 0x5a8c>, ((1, 1), (1, 39))), (<asts.types.JavaIdentifier 0x5a8d>, ((1, 1), (1, 6))), (<asts.types.JavaIdentifier 0x5a8e>, ((1, 7), (1, 17))), (<asts.types.JavaArgumentList0 0x5a8f>, ((1, 17), (1, 39))), (<asts.types.JavaFieldAccess1 0x5a90>, ((1, 19), (1, 38))), (<asts.types.JavaIdentifier 0x5a91>, ((1, 19), (1, 27))), (<asts.types.JavaIdentifier 0x5a92>, ((1, 28), (1, 38)))]
# Source Text: robot.keyRelease (KeyEvent.VK_CONTROL);, Start: 1, End: 40
# Source Text: robot.keyRelease (KeyEvent.VK_CONTROL), Start: 1, End: 39
# Source Text: robot, Start: 1, End: 6
# Source Text: keyRelease, Start: 7, End: 17
# Source Text: (KeyEvent.VK_CONTROL), Start: 17, End: 39
# Source Text: KeyEvent.VK_CONTROL, Start: 19, End: 38
# Source Text: KeyEvent, Start: 19, End: 27
# Source Text: VK_CONTROL, Start: 28, End: 38
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a8d>>
# labelselection robot
# modified code: keyRelease (KeyEvent.VK_CONTROL);
# <bound method AST.ast_at_point of <asts.types.JavaFieldAccess1 0x5a90>>
# labelselection KeyEvent.VK_CONTROL
# modified code: keyRelease ();
# keyRelease ();
# Line 9 :     System.out.println ("transform Sheet");
#
# Adjusted positions: [] 0
# Line 10 :     sheetNew.setDisplayFormulas (sheetOld.isDisplayFormulas ());
#
# Adjusted positions: [(1, 64)] 1
# Line  10 removed
# Line 11 :     sheetNew.setDisplayGridlines (sheetOld.isDisplayGridlines ());
#
# Adjusted positions: [(1, 66)] 1
# Line  11 removed
# Line 12 :     sheetNew.setDisplayGuts (sheetOld.getDisplayGuts ());
#
# Adjusted positions: [(1, 57)] 1
# Line  12 removed
# Line 13 :     sheetNew.setDisplayRowColHeadings (sheetOld.isDisplayRowColHeadings ());
#
# Adjusted positions: [(1, 76)] 1
# Line  13 removed
# Line 14 :     sheetNew.setDisplayZeros (sheetOld.isDisplayZeros ());
#
# Adjusted positions: [(1, 58)] 1
# Line  14 removed
# Line 15 :     sheetNew.setFitToPage (sheetOld.getFitToPage ());
#
# Adjusted positions: [(1, 53)] 1
# Line  15 removed
# Line 16 :     sheetNew.setHorizontallyCenter (sheetOld.getHorizontallyCenter ());
#
# Adjusted positions: [(1, 71)] 1
# Line  16 removed
# Line 17 :     sheetNew.setMargin (Sheet.BottomMargin, sheetOld.getMargin (Sheet.BottomMargin));
#
# Adjusted positions: [(1, 85)] 1
# Line  17 removed
# Line 18 :     sheetNew.setMargin (Sheet.FooterMargin, sheetOld.getMargin (Sheet.FooterMargin));
#
# Adjusted positions: [(1, 85)] 1
# Line  18 removed
# Line 19 :     sheetNew.setMargin (Sheet.HeaderMargin, sheetOld.getMargin (Sheet.HeaderMargin));
#
# Adjusted positions: [(1, 85)] 1
# Line  19 removed
# Line 20 :     sheetNew.setMargin (Sheet.LeftMargin, sheetOld.getMargin (Sheet.LeftMargin));
#
# Adjusted positions: [(1, 81)] 1
# Line  20 removed
# Line 21 :     sheetNew.setMargin (Sheet.RightMargin, sheetOld.getMargin (Sheet.RightMargin));
#
# Adjusted positions: [(1, 83)] 1
# Line  21 removed
# Line 22 :     sheetNew.setMargin (Sheet.TopMargin, sheetOld.getMargin (Sheet.TopMargin));
#
# Adjusted positions: [(1, 79)] 1
# Line  22 removed
# Line 23 :     sheetNew.setPrintGridlines (sheetNew.isPrintGridlines ());
#
# Adjusted positions: [(1, 62)] 1
# Line  23 removed
# Line 24 :     sheetNew.setRightToLeft (sheetNew.isRightToLeft ());
#
# Adjusted positions: [(1, 56)] 1
# Line  24 removed
# Line 25 :     sheetNew.setRowSumsBelow (sheetNew.getRowSumsBelow ());
#
# Adjusted positions: [(1, 59)] 1
# Line  25 removed
# Line 26 :     sheetNew.setRowSumsRight (sheetNew.getRowSumsRight ());
#
# Adjusted positions: [(1, 59)] 1
# Line  26 removed
# Line 27 :     sheetNew.setVerticallyCenter (sheetOld.getVerticallyCenter ());
#
# Adjusted positions: [(1, 67)] 1
# Line  27 removed
# Line 28 :     HSSFRow rowNew;
#
# Adjusted positions: [(1, 19)] 1
# Line  28 removed
# Line 29 :     for (Row row : sheetOld) {
#
# Adjusted positions: [(1, 30)] 1
# Line 30 :         rowNew = sheetNew.createRow (row.getRowNum ());
#
# Adjusted positions: [(1, 55)] 1
# Line  30 removed
# Line 31 :         if (rowNew != null) this.transform (workbookOld, workbookNew, (XSSFRow) row, rowNew);
#
# Adjusted positions: [(1, 93)] 1
# Line  31 removed
# Line 32 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 33 :     for (int i = 0;
#
# Adjusted positions: [(1, 19)] 1
# Line 34 :     i < this.lastColumn; i ++) {
#
# Adjusted positions: [(1, 32)] 1
# Line 35 :         sheetNew.setColumnWidth (i, sheetOld.getColumnWidth (i));
#
# Adjusted positions: [(1, 65)] 1
# Line  35 removed
# Line 36 :         sheetNew.setColumnHidden (i, sheetOld.isColumnHidden (i));
#
# Adjusted positions: [(1, 66)] 1
# Line  36 removed
# Line 37 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 38 :     for (int i = 0;
#
# Adjusted positions: [(1, 19)] 1
# Line 39 :     i < sheetOld.getNumMergedRegions (); i ++) {
#
# Adjusted positions: [(1, 48)] 1
# Line 40 :         CellRangeAddress merged = sheetOld.getMergedRegion (i);
#
# Adjusted positions: [(1, 63)] 1
# Line  40 removed
# Line 41 :         sheetNew.addMergedRegion (merged);
#
# Adjusted positions: [(1, 42)] 1
# Line  41 removed
# Line 42 :     }
#
# Adjusted positions: [(1, 5)] 1
# Line 46 :     styleNew.setAlignment (styleOld.getAlignment ());
#
# Adjusted positions: [(1, 53)] 1
# Line  46 removed
# Line 47 :     styleNew.setBorderBottom (styleOld.getBorderBottom ());
#
# Adjusted positions: [(1, 59)] 1
# Line  47 removed
# Line 48 :     styleNew.setBorderLeft (styleOld.getBorderLeft ());
#
# Adjusted positions: [(1, 55)] 1
# Line  48 removed
# Line 49 :     styleNew.setBorderRight (styleOld.getBorderRight ());
#
# Adjusted positions: [(1, 57)] 1
# Line  49 removed
# Line 50 :     styleNew.setBorderTop (styleOld.getBorderTop ());
#
# Adjusted positions: [(1, 53)] 1
# Line  50 removed
# Line 51 :     styleNew.setDataFormat (this.transform (workbookOld, workbookNew, styleOld.getDataFormat ()));
#
# Adjusted positions: [(1, 98)] 1
# Line  51 removed
# Line 52 :     styleNew.setFillBackgroundColor (styleOld.getFillBackgroundColor ());
#
# Adjusted positions: [(1, 73)] 1
# Line  52 removed
# Line 53 :     styleNew.setFillForegroundColor (styleOld.getFillForegroundColor ());
#
# Adjusted positions: [(1, 73)] 1
# Line  53 removed
# Line 54 :     styleNew.setFillPattern (styleOld.getFillPattern ());
#
# Adjusted positions: [(1, 57)] 1
# Line  54 removed
# Line 55 :     styleNew.setFont (this.transform (workbookNew, styleOld.getFont (workbookOld)));
#
# Adjusted positions: [(1, 84)] 1
# Line  55 removed
# Line 56 :     styleNew.setHidden (styleOld.getHidden ());
#
# Adjusted positions: [(1, 47)] 1
# Line  56 removed
# Line 57 :     styleNew.setIndention (styleOld.getIndention ());
#
# Adjusted positions: [(1, 53)] 1
# Line  57 removed
# Line 58 :     styleNew.setLocked (styleOld.getLocked ());
#
# Adjusted positions: [(1, 47)] 1
# Line  58 removed
# Line 59 :     styleNew.setVerticalAlignment (styleOld.getVerticalAlignment ());
#
# Adjusted positions: [(1, 69)] 1
# Line  59 removed
# Line 60 :     styleNew.setWrapText (styleOld.getWrapText ());
#
# Adjusted positions: [(1, 51)] 1
# Line  60 removed
# Line 61 :     this.styleMap.put (hash, styleNew);
#
# Adjusted positions: [(1, 39)] 1
# Line  61 removed
# Line 32 :     double sun = getExpensesForDay (myScanner, "Sunday");
#
# Adjusted positions: [(14, 17), (17, 56)] 2
# Line  32 mutated to
# [(11, 14), (14, 53)]
# [(<asts.types.JavaLocalVariableDeclaration1 0x5a99>, ((1, 1), (1, 54))), (<asts.types.JavaFloatingPointType 0x5a9a>, ((1, 1), (1, 7))), (<asts.types.JavaVariableDeclarator0 0x5a9b>, ((1, 7), (1, 53))), (<asts.types.JavaIdentifier 0x5a9c>, ((1, 8), (1, 12))), (<asts.types.JavaMethodInvocation0 0x5a9d>, ((1, 13), (1, 53))), (<asts.types.JavaIdentifier 0x5a9e>, ((1, 14), (1, 31))), (<asts.types.JavaArgumentList0 0x5a9f>, ((1, 31), (1, 53))), (<asts.types.JavaIdentifier 0x5aa0>, ((1, 33), (1, 42))), (<asts.types.JavaStringLiteral 0x5aa1>, ((1, 43), (1, 52)))]
# Source Text: double sun = getExpensesForDay (myScanner, "Sunday");, Start: 1, End: 54
# Source Text: double, Start: 1, End: 7
# Source Text: sun = getExpensesForDay (myScanner, "Sunday"), Start: 7, End: 53
# Source Text: sun, Start: 8, End: 12
# Source Text: getExpensesForDay (myScanner, "Sunday"), Start: 13, End: 53
# Source Text: getExpensesForDay, Start: 14, End: 31
# Source Text: (myScanner, "Sunday"), Start: 31, End: 53
# Source Text: myScanner, Start: 33, End: 42
# Source Text: "Sunday", Start: 43, End: 52
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5a9c>>
# labelselection sun
# cannot cut node
# Node is not processed: <asts.types.JavaIdentifier 0x5a9c> <asts.types.JavaVariableDeclarator0 0x5a9b> Clone131.java 32 sun
# Line  32 removed
# Line 26 :     double mon = getExpensesForDay (myScanner, "Monday");
#
# Adjusted positions: [] 0
# Line 27 :     double tues = getExpensesForDay (myScanner, "Tuesday");
#
# Adjusted positions: [(15, 18), (18, 58)] 2
# Line  27 mutated to
# [(12, 15), (15, 55)]
# [(<asts.types.JavaLocalVariableDeclaration1 0x5aa5>, ((1, 1), (1, 56))), (<asts.types.JavaFloatingPointType 0x5aa6>, ((1, 1), (1, 7))), (<asts.types.JavaVariableDeclarator0 0x5aa7>, ((1, 7), (1, 55))), (<asts.types.JavaIdentifier 0x5aa8>, ((1, 8), (1, 13))), (<asts.types.JavaMethodInvocation0 0x5aa9>, ((1, 14), (1, 55))), (<asts.types.JavaIdentifier 0x5aaa>, ((1, 15), (1, 32))), (<asts.types.JavaArgumentList0 0x5aab>, ((1, 32), (1, 55))), (<asts.types.JavaIdentifier 0x5aac>, ((1, 34), (1, 43))), (<asts.types.JavaStringLiteral 0x5aad>, ((1, 44), (1, 54)))]
# Source Text: double tues = getExpensesForDay (myScanner, "Tuesday");, Start: 1, End: 56
# Source Text: double, Start: 1, End: 7
# Source Text: tues = getExpensesForDay (myScanner, "Tuesday"), Start: 7, End: 55
# Source Text: tues, Start: 8, End: 13
# Source Text: getExpensesForDay (myScanner, "Tuesday"), Start: 14, End: 55
# Source Text: getExpensesForDay, Start: 15, End: 32
# Source Text: (myScanner, "Tuesday"), Start: 32, End: 55
# Source Text: myScanner, Start: 34, End: 43
# Source Text: "Tuesday", Start: 44, End: 54
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5aa8>>
# labelselection tues
# cannot cut node
# Node is not processed: <asts.types.JavaIdentifier 0x5aa8> <asts.types.JavaVariableDeclarator0 0x5aa7> Clone131.java 27 tues
# Line  27 removed
# Line 28 :     double wed = getExpensesForDay (myScanner, "Wednesday");
#
# Adjusted positions: [(14, 17), (17, 59)] 2
# Line  28 mutated to
# [(11, 14), (14, 56)]
# [(<asts.types.JavaLocalVariableDeclaration1 0x5ab1>, ((1, 1), (1, 57))), (<asts.types.JavaFloatingPointType 0x5ab2>, ((1, 1), (1, 7))), (<asts.types.JavaVariableDeclarator0 0x5ab3>, ((1, 7), (1, 56))), (<asts.types.JavaIdentifier 0x5ab4>, ((1, 8), (1, 12))), (<asts.types.JavaMethodInvocation0 0x5ab5>, ((1, 13), (1, 56))), (<asts.types.JavaIdentifier 0x5ab6>, ((1, 14), (1, 31))), (<asts.types.JavaArgumentList0 0x5ab7>, ((1, 31), (1, 56))), (<asts.types.JavaIdentifier 0x5ab8>, ((1, 33), (1, 42))), (<asts.types.JavaStringLiteral 0x5ab9>, ((1, 43), (1, 55)))]
# Source Text: double wed = getExpensesForDay (myScanner, "Wednesday");, Start: 1, End: 57
# Source Text: double, Start: 1, End: 7
# Source Text: wed = getExpensesForDay (myScanner, "Wednesday"), Start: 7, End: 56
# Source Text: wed, Start: 8, End: 12
# Source Text: getExpensesForDay (myScanner, "Wednesday"), Start: 13, End: 56
# Source Text: getExpensesForDay, Start: 14, End: 31
# Source Text: (myScanner, "Wednesday"), Start: 31, End: 56
# Source Text: myScanner, Start: 33, End: 42
# Source Text: "Wednesday", Start: 43, End: 55
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5ab4>>
# labelselection wed
# cannot cut node
# Node is not processed: <asts.types.JavaIdentifier 0x5ab4> <asts.types.JavaVariableDeclarator0 0x5ab3> Clone131.java 28 wed
# Line  28 removed
# Line 29 :     double thurs = getExpensesForDay (myScanner, "Thursday");
#
# Adjusted positions: [(16, 19), (19, 60)] 2
# Line  29 mutated to
# [(13, 16), (16, 57)]
# [(<asts.types.JavaLocalVariableDeclaration1 0x5abd>, ((1, 1), (1, 58))), (<asts.types.JavaFloatingPointType 0x5abe>, ((1, 1), (1, 7))), (<asts.types.JavaVariableDeclarator0 0x5abf>, ((1, 7), (1, 57))), (<asts.types.JavaIdentifier 0x5ac0>, ((1, 8), (1, 14))), (<asts.types.JavaMethodInvocation0 0x5ac1>, ((1, 15), (1, 57))), (<asts.types.JavaIdentifier 0x5ac2>, ((1, 16), (1, 33))), (<asts.types.JavaArgumentList0 0x5ac3>, ((1, 33), (1, 57))), (<asts.types.JavaIdentifier 0x5ac4>, ((1, 35), (1, 44))), (<asts.types.JavaStringLiteral 0x5ac5>, ((1, 45), (1, 56)))]
# Source Text: double thurs = getExpensesForDay (myScanner, "Thursday");, Start: 1, End: 58
# Source Text: double, Start: 1, End: 7
# Source Text: thurs = getExpensesForDay (myScanner, "Thursday"), Start: 7, End: 57
# Source Text: thurs, Start: 8, End: 14
# Source Text: getExpensesForDay (myScanner, "Thursday"), Start: 15, End: 57
# Source Text: getExpensesForDay, Start: 16, End: 33
# Source Text: (myScanner, "Thursday"), Start: 33, End: 57
# Source Text: myScanner, Start: 35, End: 44
# Source Text: "Thursday", Start: 45, End: 56
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5ac0>>
# labelselection thurs
# cannot cut node
# Node is not processed: <asts.types.JavaIdentifier 0x5ac0> <asts.types.JavaVariableDeclarator0 0x5abf> Clone131.java 29 thurs
# Line  29 removed
# Line 30 :     double fri = getExpensesForDay (myScanner, "Friday");
#
# Adjusted positions: [(14, 17), (17, 56)] 2
# Line  30 mutated to
# [(11, 14), (14, 53)]
# [(<asts.types.JavaLocalVariableDeclaration1 0x5ac9>, ((1, 1), (1, 54))), (<asts.types.JavaFloatingPointType 0x5aca>, ((1, 1), (1, 7))), (<asts.types.JavaVariableDeclarator0 0x5acb>, ((1, 7), (1, 53))), (<asts.types.JavaIdentifier 0x5acc>, ((1, 8), (1, 12))), (<asts.types.JavaMethodInvocation0 0x5acd>, ((1, 13), (1, 53))), (<asts.types.JavaIdentifier 0x5ace>, ((1, 14), (1, 31))), (<asts.types.JavaArgumentList0 0x5acf>, ((1, 31), (1, 53))), (<asts.types.JavaIdentifier 0x5ad0>, ((1, 33), (1, 42))), (<asts.types.JavaStringLiteral 0x5ad1>, ((1, 43), (1, 52)))]
# Source Text: double fri = getExpensesForDay (myScanner, "Friday");, Start: 1, End: 54
# Source Text: double, Start: 1, End: 7
# Source Text: fri = getExpensesForDay (myScanner, "Friday"), Start: 7, End: 53
# Source Text: fri, Start: 8, End: 12
# Source Text: getExpensesForDay (myScanner, "Friday"), Start: 13, End: 53
# Source Text: getExpensesForDay, Start: 14, End: 31
# Source Text: (myScanner, "Friday"), Start: 31, End: 53
# Source Text: myScanner, Start: 33, End: 42
# Source Text: "Friday", Start: 43, End: 52
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5acc>>
# labelselection fri
# cannot cut node
# Node is not processed: <asts.types.JavaIdentifier 0x5acc> <asts.types.JavaVariableDeclarator0 0x5acb> Clone131.java 30 fri
# Line  30 removed
# Line 31 :     double sat = getExpensesForDay (myScanner, "Saturday");
#
# Adjusted positions: [(14, 17), (17, 58)] 2
# Line  31 mutated to
# [(11, 14), (14, 55)]
# [(<asts.types.JavaLocalVariableDeclaration1 0x5ad5>, ((1, 1), (1, 56))), (<asts.types.JavaFloatingPointType 0x5ad6>, ((1, 1), (1, 7))), (<asts.types.JavaVariableDeclarator0 0x5ad7>, ((1, 7), (1, 55))), (<asts.types.JavaIdentifier 0x5ad8>, ((1, 8), (1, 12))), (<asts.types.JavaMethodInvocation0 0x5ad9>, ((1, 13), (1, 55))), (<asts.types.JavaIdentifier 0x5ada>, ((1, 14), (1, 31))), (<asts.types.JavaArgumentList0 0x5adb>, ((1, 31), (1, 55))), (<asts.types.JavaIdentifier 0x5adc>, ((1, 33), (1, 42))), (<asts.types.JavaStringLiteral 0x5add>, ((1, 43), (1, 54)))]
# Source Text: double sat = getExpensesForDay (myScanner, "Saturday");, Start: 1, End: 56
# Source Text: double, Start: 1, End: 7
# Source Text: sat = getExpensesForDay (myScanner, "Saturday"), Start: 7, End: 55
# Source Text: sat, Start: 8, End: 12
# Source Text: getExpensesForDay (myScanner, "Saturday"), Start: 13, End: 55
# Source Text: getExpensesForDay, Start: 14, End: 31
# Source Text: (myScanner, "Saturday"), Start: 31, End: 55
# Source Text: myScanner, Start: 33, End: 42
# Source Text: "Saturday", Start: 43, End: 54
# <bound method AST.ast_at_point of <asts.types.JavaIdentifier 0x5ad8>>
# labelselection sat
# cannot cut node
# Node is not processed: <asts.types.JavaIdentifier 0x5ad8> <asts.types.JavaVariableDeclarator0 0x5ad7> Clone131.java 31 sat
# Line  31 removed
# Line 34 :         XMLInputFactory factory = XMLInputFactory.newInstance ();
#
# Adjusted positions: [(1, 65)] 1
# Line  34 removed
# Line 35 :         XMLEventReader eventReader = factory.createXMLEventReader (new FileReader ("c:\\staxTestFile.xml"));
#
# Adjusted positions: [(1, 108)] 1
# Line  35 removed
# Line 36 :         while (eventReader.hasNext ()) {
#
# Adjusted positions: [(1, 40)] 1
# Line 37 :             XMLEvent event = eventReader.nextEvent ();
#
# Adjusted positions: [(1, 54)] 1
# Line  37 removed
# Line 38 :             switch (event.getEventType ()) {
#
# Adjusted positions: [(1, 44)] 1
# Line 39 :                 case XMLStreamConstants.START_ELEMENT :
#
# Adjusted positions: [(1, 55)] 1
# Line  39 removed
# Line 40 :                     StartElement startElement = event.asStartElement ();
#
# Adjusted positions: [(1, 72)] 1
# Line  40 removed
# Line 41 :                     String qName = startElement.getName ().getLocalPart ();
#
# Adjusted positions: [(1, 75)] 1
# Line  41 removed
# Line 42 :                     if (qName.equalsIgnoreCase ("Part")) {
#
# Adjusted positions: [(1, 58)] 1
# Line 43 :                         System.out.println ("Start Element : Part");
#
# Adjusted positions: [(1, 68)] 1
# Line  43 removed
# Line 44 :                         Iterator < Attribute > attributes = startElement.getAttributes ();
#
# Adjusted positions: [(1, 90)] 1
# Line  44 removed
# Line 45 :                     } else if (qName.equalsIgnoreCase ("ObjectID")) {
#
# Adjusted positions: [(1, 69)] 1
# Line 46 :                         ObjectID = true;
#
# Adjusted positions: [(1, 40)] 1
# Line  46 removed
# Line 47 :                     } else if (qName.equalsIgnoreCase ("Class")) {
#
# Adjusted positions: [(1, 66)] 1
# Line 48 :                         Class = true;
#
# Adjusted positions: [(1, 37)] 1
# Line  48 removed
# Line 49 :                     } else if (qName.equalsIgnoreCase ("LastChangedBy")) {
#
# Adjusted positions: [(1, 74)] 1
# Line 50 :                         LastChangedBy = true;
#
# Adjusted positions: [(1, 45)] 1
# Line  50 removed
# Line 51 :                     } else if (qName.equalsIgnoreCase ("Number")) {
#
# Adjusted positions: [(1, 67)] 1
# Line 52 :                         Number = true;
#
# Adjusted positions: [(1, 38)] 1
# Line  52 removed
# Line 53 :                     } else if (qName.equalsIgnoreCase ("StartEffectivity")) {
#
# Adjusted positions: [(1, 77)] 1
# Line 54 :                         StartEffectivity = true;
#
# Adjusted positions: [(1, 48)] 1
# Line  54 removed
# Line 55 :                     } else if (qName.equalsIgnoreCase ("EndSerialNumberEffectivity")) {
#
# Adjusted positions: [(1, 87)] 1
# Line 56 :                         EndSerialNumberEffectivity = true;
#
# Adjusted positions: [(1, 58)] 1
# Line  56 removed
# Line 57 :                     } else if (qName.equalsIgnoreCase ("StartSerialNumberEffectivity")) {
#
# Adjusted positions: [(1, 89)] 1
# Line 58 :                         StartSerialNumberEffectivity = true;
#
# Adjusted positions: [(1, 60)] 1
# Line  58 removed
# Line 59 :                     } else if (qName.equalsIgnoreCase ("EndSerialNumberEffectivity")) {
#
# Adjusted positions: [(1, 87)] 1
# Line 60 :                         EndSerialNumberEffectivity = true;
#
# Adjusted positions: [(1, 58)] 1
# Line  60 removed
# Line 61 :                     } else if (qName.equalsIgnoreCase ("StartLotNumberEffectivity")) {
#
# Adjusted positions: [(1, 86)] 1
# Line 62 :                         StartLotNumberEffectivity = true;
#
# Adjusted positions: [(1, 57)] 1
# Line  62 removed
# Line 63 :                     } else if (qName.equalsIgnoreCase ("EndLotNumberEffectivity")) {
#
# Adjusted positions: [(1, 84)] 1
# Line 64 :                         EndLotNumberEffectivity = true;
#
# Adjusted positions: [(1, 55)] 1
# Line  64 removed
# Line 65 :                     } else if (qName.equalsIgnoreCase ("SerialNumberEffectivityCxtPartNumber")) {
#
# Adjusted positions: [(1, 97)] 1
# Line 66 :                         SerialNumberEffectivityCxtPartNumber = true;
#
# Adjusted positions: [(1, 68)] 1
# Line  66 removed
# Line 67 :                     } else if (qName.equalsIgnoreCase ("LotNumberEffectivityCxtPartNumber")) {
#
# Adjusted positions: [(1, 94)] 1
# Line 68 :                         LotNumberEffectivityCxtPartNumber = true;
#
# Adjusted positions: [(1, 65)] 1
# Line  68 removed
# Line 69 :                     } else if (qName.equalsIgnoreCase ("DefaultUnit")) {
#
# Adjusted positions: [(1, 72)] 1
# Line 70 :                         DefaultUnit = true;
#
# Adjusted positions: [(1, 43)] 1
# Line  70 removed
# Line 71 :                     } else if (qName.equalsIgnoreCase ("Name")) {
#
# Adjusted positions: [(1, 65)] 1
# Line 72 :                         Name = true;
#
# Adjusted positions: [(1, 36)] 1
# Line  72 removed
# Line 73 :                     } else if (qName.equalsIgnoreCase ("PartType")) {
#
# Adjusted positions: [(1, 69)] 1
# Line 74 :                         PartType = true;
#
# Adjusted positions: [(1, 40)] 1
# Line  74 removed
# Line 75 :                     } else if (qName.equalsIgnoreCase ("Source")) {
#
# Adjusted positions: [(1, 67)] 1
# Line 76 :                         Source = true;
#
# Adjusted positions: [(1, 38)] 1
# Line  76 removed
# Line 77 :                     } else if (qName.equalsIgnoreCase ("State")) {
#
# Adjusted positions: [(1, 66)] 1
# Line 78 :                         State = true;
#
# Adjusted positions: [(1, 37)] 1
# Line  78 removed
# Line 79 :                     } else if (qName.equalsIgnoreCase ("IsPhantom")) {
#
# Adjusted positions: [(1, 70)] 1
# Line 80 :                         IsPhantom = true;
#
# Adjusted positions: [(1, 41)] 1
# Line  80 removed
# Line 81 :                     } else if (qName.equalsIgnoreCase ("Version")) {
#
# Adjusted positions: [(1, 68)] 1
# Line 82 :                         Version = true;
#
# Adjusted positions: [(1, 39)] 1
# Line  82 removed
# Line 83 :                     } else if (qName.equalsIgnoreCase ("Iteration")) {
#
# Adjusted positions: [(1, 70)] 1
# Line 84 :                         Iteration = true;
#
# Adjusted positions: [(1, 41)] 1
# Line  84 removed
# Line 85 :                     } else if (qName.equalsIgnoreCase ("PreviousVersion")) {
#
# Adjusted positions: [(1, 76)] 1
# Line 86 :                         PreviousVersion = true;
#
# Adjusted positions: [(1, 47)] 1
# Line  86 removed
# Line 87 :                     } else if (qName.equalsIgnoreCase ("IsConfigurable")) {
#
# Adjusted positions: [(1, 75)] 1
# Line 88 :                         IsConfigurable = true;
#
# Adjusted positions: [(1, 46)] 1
# Line  88 removed
# Line 89 :                     } else if (qName.equalsIgnoreCase ("IsCollapsible")) {
#
# Adjusted positions: [(1, 74)] 1
# Line 90 :                         IsCollapsible = true;
#
# Adjusted positions: [(1, 45)] 1
# Line  90 removed
# Line 91 :                     } else if (qName.equalsIgnoreCase ("TargetID")) {
#
# Adjusted positions: [(1, 69)] 1
# Line 92 :                         TargetID = true;
#
# Adjusted positions: [(1, 40)] 1
# Line  92 removed
# Line 93 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 94 :                     break;
#
# Adjusted positions: [(1, 26)] 1
# Line  94 removed
# Line 95 :                 case XMLStreamConstants.CHARACTERS :
#
# Adjusted positions: [(1, 52)] 1
# Line  95 removed
# Line 96 :                     Characters characters = event.asCharacters ();
#
# Adjusted positions: [(1, 66)] 1
# Line  96 removed
# Line 97 :                     if (ObjectID) {
#
# Adjusted positions: [(1, 35)] 1
# Line 98 :                         System.out.println ("ObjectID: " + characters.getData ());
#
# Adjusted positions: [(1, 82)] 1
# Line  98 removed
# Line 99 :                         ObjectID = false;
#
# Adjusted positions: [(1, 41)] 1
# Line  99 removed
# Line 100 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 101 :                     if (Class) {
#
# Adjusted positions: [(1, 32)] 1
# Line 102 :                         System.out.println ("Class: " + characters.getData ());
#
# Adjusted positions: [(1, 79)] 1
# Line  102 removed
# Line 103 :                         Class = false;
#
# Adjusted positions: [(1, 38)] 1
# Line  103 removed
# Line 104 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 105 :                     if (LastChangedBy) {
#
# Adjusted positions: [(1, 40)] 1
# Line 106 :                         System.out.println ("LastChangedBy " + characters.getData ());
#
# Adjusted positions: [(1, 86)] 1
# Line  106 removed
# Line 107 :                         LastChangedBy = false;
#
# Adjusted positions: [(1, 46)] 1
# Line  107 removed
# Line 108 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 109 :                     if (Number) {
#
# Adjusted positions: [(1, 33)] 1
# Line 110 :                         System.out.println ("Number: " + characters.getData ());
#
# Adjusted positions: [(1, 80)] 1
# Line  110 removed
# Line 111 :                         Number = false;
#
# Adjusted positions: [(1, 39)] 1
# Line  111 removed
# Line 112 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 113 :                     if (StartEffectivity) {
#
# Adjusted positions: [(1, 43)] 1
# Line 114 :                         System.out.println ("StartEffectivity: " + characters.getData ());
#
# Adjusted positions: [(1, 90)] 1
# Line  114 removed
# Line 115 :                         StartEffectivity = false;
#
# Adjusted positions: [(1, 49)] 1
# Line  115 removed
# Line 116 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 117 :                     if (EndEffectivity) {
#
# Adjusted positions: [(1, 41)] 1
# Line 118 :                         System.out.println ("EndEffectivity " + characters.getData ());
#
# Adjusted positions: [(1, 87)] 1
# Line  118 removed
# Line 119 :                         EndEffectivity = false;
#
# Adjusted positions: [(1, 47)] 1
# Line  119 removed
# Line 120 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 121 :                     if (StartSerialNumberEffectivity) {
#
# Adjusted positions: [(1, 55)] 1
# Line 122 :                         System.out.println ("StartSerialNumberEffectivity " + characters.getData ());
#
# Adjusted positions: [(1, 101)] 1
# Line  122 removed
# Line 123 :                         StartSerialNumberEffectivity = false;
#
# Adjusted positions: [(1, 61)] 1
# Line  123 removed
# Line 124 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 125 :                     if (EndSerialNumberEffectivity) {
#
# Adjusted positions: [(1, 53)] 1
# Line 126 :                         System.out.println ("EndSerialNumberEffectivity: " + characters.getData ());
#
# Adjusted positions: [(1, 100)] 1
# Line  126 removed
# Line 127 :                         EndSerialNumberEffectivity = false;
#
# Adjusted positions: [(1, 59)] 1
# Line  127 removed
# Line 128 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 129 :                     if (StartLotNumberEffectivity) {
#
# Adjusted positions: [(1, 52)] 1
# Line 130 :                         System.out.println ("StartLotNumberEffectivity" + characters.getData ());
#
# Adjusted positions: [(1, 97)] 1
# Line  130 removed
# Line 131 :                         StartLotNumberEffectivity = false;
#
# Adjusted positions: [(1, 58)] 1
# Line  131 removed
# Line 132 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 133 :                     if (EndLotNumberEffectivity) {
#
# Adjusted positions: [(1, 50)] 1
# Line 134 :                         System.out.println ("EndLotNumberEffectivity: " + characters.getData ());
#
# Adjusted positions: [(1, 97)] 1
# Line  134 removed
# Line 135 :                         EndLotNumberEffectivity = false;
#
# Adjusted positions: [(1, 56)] 1
# Line  135 removed
# Line 136 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 137 :                     if (SerialNumberEffectivityCxtPartNumber) {
#
# Adjusted positions: [(1, 63)] 1
# Line 138 :                         System.out.println ("SerialNumberEffectivityCxtPartNumber " + characters.getData ());
#
# Adjusted positions: [(1, 109)] 1
# Line  138 removed
# Line 139 :                         SerialNumberEffectivityCxtPartNumber = false;
#
# Adjusted positions: [(1, 69)] 1
# Line  139 removed
# Line 140 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 141 :                     if (LotNumberEffectivityCxtPartNumber) {
#
# Adjusted positions: [(1, 60)] 1
# Line 142 :                         System.out.println ("LotNumberEffectivityCxtPartNumber: " + characters.getData ());
#
# Adjusted positions: [(1, 107)] 1
# Line  142 removed
# Line 143 :                         LotNumberEffectivityCxtPartNumber = false;
#
# Adjusted positions: [(1, 66)] 1
# Line  143 removed
# Line 144 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 145 :                     if (DefaultUnit) {
#
# Adjusted positions: [(1, 38)] 1
# Line 146 :                         System.out.println ("DefaultUnit: " + characters.getData ());
#
# Adjusted positions: [(1, 85)] 1
# Line  146 removed
# Line 147 :                         DefaultUnit = false;
#
# Adjusted positions: [(1, 44)] 1
# Line  147 removed
# Line 148 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 149 :                     if (Name) {
#
# Adjusted positions: [(1, 31)] 1
# Line 150 :                         System.out.println ("Name: " + characters.getData ());
#
# Adjusted positions: [(1, 78)] 1
# Line  150 removed
# Line 151 :                         Name = false;
#
# Adjusted positions: [(1, 37)] 1
# Line  151 removed
# Line 152 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 153 :                     if (PartType) {
#
# Adjusted positions: [(1, 35)] 1
# Line 154 :                         System.out.println ("PartType: " + characters.getData ());
#
# Adjusted positions: [(1, 82)] 1
# Line  154 removed
# Line 155 :                         PartType = false;
#
# Adjusted positions: [(1, 41)] 1
# Line  155 removed
# Line 156 :                     }
#
# Adjusted positions: [(1, 21)] 1
# Line 157 :                     if (Source) {
#
# Adjusted positions: [(1, 33)] 1
# Line 158 :                         System.out.println ("Source: " + characters.getData ());
#
# Adjusted positions: [(1, 80)] 1
# Line  158 removed
# Line 159 :                         Source = false;
#
# Adjusted positions: [(1, 39)] 1
# Line  159 removed
# ...
# Clone441.java 14  remove
# Clone441.java 15 { mutate
# Clone441.java 16  remove
# Clone441.java 17  remove
# Clone441.java 18  remove
# Clone441.java 19  remove
# Clone441.java 20  remove
# Clone441.java 21  remove
# Clone441.java 22  remove
# Clone441.java 23  remove
# Clone441.java 24 } mutate
# Clone441.java 31 { mutate
# Clone441.java 32  remove
# Clone441.java 33 } mutate
# Clone441.java 34 { mutate
# Clone441.java 35  remove
# Clone441.java 36 } mutate
# Clone441.java 37  remove
# Clone441.java 38 ( mutate
# Clone441.java 39 ){ mutate
# Clone441.java 40  remove
# Clone441.java 41 } mutate
# Clone441.java 42  remove
# Clone441.java 43 ( mutate
# Clone441.java 44 ){ mutate
# Clone441.java 45  remove
# Clone441.java 46 } mutate
# Clone441.java 47  remove
# Clone524.java 10  remove
# Clone524.java 12 { mutate
# Clone524.java 13  remove
# Clone524.java 14 { mutate
# Clone524.java 15  remove
# Clone524.java 16 ( mutate
# Clone524.java 17 ){ mutate
# Clone524.java 18  remove
# Clone524.java 19  remove
# Clone524.java 20 } mutate
# Clone524.java 21 }{ mutate
# Clone524.java 22  remove
# Clone524.java 24 } mutate
# Clone524.java 29  remove
# Clone524.java 30  remove
# Clone524.java 33 { mutate
# Clone524.java 34 { mutate
# Clone524.java 35  remove
# Clone524.java 36 }{ mutate
# Clone524.java 37  remove
# Clone524.java 38 } mutate
# Clone524.java 39  remove
# Clone524.java 40 } mutate
# Clone869.java 10  remove
# Clone869.java 12 { mutate
# Clone869.java 13  remove
# Clone869.java 14 }{ mutate
# Clone869.java 15  remove
# Clone869.java 16 } mutate
# Clone869.java 21  remove
# Clone869.java 22  remove
# Clone869.java 23 { mutate
# Clone869.java 24  remove
# Clone869.java 25  remove
# Clone869.java 26 }{ mutate
# Clone869.java 27  remove
# Clone869.java 28  remove
# Clone869.java 29 } mutate
# Clone589.java 10  remove
# Clone589.java 11  remove
# Clone589.java 15  remove
# Clone589.java 16  remove
# Clone589.java 17  remove
# Clone589.java 21  remove
# Clone589.java 22  remove
# Clone589.java 24  remove
# Clone589.java 25 { mutate
# Clone589.java 26  remove
# Clone589.java 27 } mutate
# Clone671.java 12  remove
# Clone671.java 13  remove
# Clone671.java 14  remove
# Clone671.java 24 ( mutate
# Clone671.java 25 ){ mutate
# Clone671.java 26  remove
# Clone671.java 27 } mutate
# Clone455.java 15 {( mutate
# Clone455.java 16  remove
# Clone455.java 17 { mutate
# Clone455.java 18  remove
# Clone455.java 19 } mutate
# Clone455.java 20 { mutate
# Clone455.java 21 ( mutate
# Clone455.java 22 ){ mutate
# Clone455.java 23  remove
# Clone455.java 24 { mutate
# Clone455.java 25 { mutate
# Clone455.java 26  remove
# Clone455.java 27 } mutate
# Clone455.java 28 } mutate
# Clone455.java 29 } mutate
# Clone455.java 30  remove
# Clone455.java 31 }} mutate
# Clone455.java 32 ) mutate
# Clone455.java 34  remove
# Clone455.java 44  remove
# Clone82.java 10  remove
# Clone82.java 11 String lsInsert ; mutate
# Clone82.java 13 String lsText ; mutate
# Clone82.java 14 Log.d ("debug"); mutate
# Clone82.java 15 Log.d ("debug"); mutate
# Clone82.java 17 { mutate
# Clone82.java 18  remove
# Clone82.java 19  remove
# Clone82.java 20 { mutate
# Clone82.java 21  remove
# Clone82.java 22  remove
# Clone82.java 23 } mutate
# Clone82.java 24  remove
# Clone82.java 25  remove
# Clone82.java 26  remove
# Clone82.java 27  remove
# Clone82.java 28 } mutate
# Clone82.java 29  remove
# Clone82.java 31 { mutate
# Clone82.java 33 } mutate
# Clone82.java 38  remove
# Clone82.java 39  remove
# Clone82.java 40 ( mutate
# Clone82.java 41 ){ mutate
# Clone82.java 42  remove
# Clone82.java 43 { mutate
# Clone82.java 44  remove
# Clone82.java 45  remove
# Clone82.java 46 } mutate
# Clone82.java 47 } mutate
# Clone82.java 48 { mutate
# Clone82.java 49 { mutate
# Clone82.java 51 } mutate
# Clone82.java 52 { mutate
# Clone82.java 54 } mutate
# Clone82.java 55 { mutate
# Clone82.java 57 } mutate
# Clone82.java 58 } mutate
# Clone138.java 10  remove
# Clone138.java 11 { mutate
# Clone138.java 12  remove
# Clone138.java 13  remove
# Clone138.java 14  remove
# Clone138.java 15 } mutate
# Clone138.java 16  remove
# Clone138.java 17  remove
# Clone138.java 21  remove
# Clone138.java 22 { mutate
# Clone138.java 23 { mutate
# Clone138.java 24  remove
# Clone138.java 25 } mutate
# Clone138.java 26  remove
# Clone138.java 27  remove
# Clone138.java 28 }{ mutate
# Clone138.java 29  remove
# Clone138.java 30 } mutate
# Clone485.java 26  remove
# Clone485.java 27  remove
# Clone485.java 28  remove
# Clone485.java 29 ( mutate
# Clone485.java 30 ){ mutate
# Clone485.java 31  remove
# Clone485.java 32  remove
# Clone485.java 33  remove
# Clone485.java 34 } mutate
# Clone485.java 35  remove
# Clone485.java 36  remove
# Clone485.java 37  remove
# Clone485.java 38 ( mutate
# Clone485.java 39 ){ mutate
# Clone485.java 40  remove
# Clone485.java 41  remove
# Clone485.java 42  remove
# Clone485.java 43  remove
# Clone485.java 44 { mutate
# Clone485.java 45  remove
# Clone485.java 46  remove
# Clone485.java 47  remove
# Clone485.java 48  remove
# Clone485.java 52 } mutate
# Clone485.java 53  remove
# Clone485.java 54 } mutate
# Clone485.java 55 ( mutate
# Clone485.java 56 ){ mutate
# Clone485.java 57 { mutate
# Clone485.java 58  remove
# Clone485.java 59  remove
# Clone485.java 60  remove
# Clone485.java 61  remove
# Clone485.java 62 { mutate
# Clone485.java 63  remove
# Clone485.java 64  remove
# Clone485.java 65  remove
# Clone485.java 66  remove
# Clone485.java 70 } mutate
# Clone485.java 71  remove
# Clone485.java 72 } mutate
# Clone485.java 73 } mutate
# Clone485.java 74  remove
# Clone485.java 75  remove
# Clone485.java 76  remove
# Clone485.java 77  remove
# Clone485.java 78  remove
# Clone485.java 79 ( mutate
# Clone485.java 80 ){ mutate
# Clone485.java 81  remove
# Clone485.java 82  remove
# Clone485.java 83  remove
# Clone485.java 84  remove
# Clone485.java 85  remove
# Clone485.java 86 } mutate
# Clone485.java 87  remove
# Clone485.java 88  remove
# Clone485.java 89 ( mutate
# Clone485.java 90 ){ mutate
# Clone485.java 91  remove
# Clone485.java 92  remove
# Clone485.java 93  remove
# Clone485.java 94  remove
# Clone485.java 95  remove
# Clone485.java 96 } mutate
# Clone632.java 10  remove
# Clone632.java 11  remove
# Clone632.java 12  remove
# Clone632.java 13  remove
# Clone632.java 15 { mutate
# Clone632.java 16  remove
# Clone632.java 17 }{ mutate
# Clone632.java 18 ) mutate
# Clone632.java 19  remove
# Clone632.java 20 } mutate
# Clone632.java 24 { mutate
# Clone632.java 25  remove
# Clone632.java 26 } mutate
# Clone632.java 27 { mutate
# Clone632.java 28  remove
# Clone632.java 29  remove
# Clone632.java 30 } mutate
# Clone132.java 11  remove
# Clone132.java 12  remove
# Clone132.java 13 { mutate
# Clone132.java 14  remove
# Clone132.java 15 }{ mutate
# Clone132.java 16  remove
# Clone132.java 17 } mutate
# Clone132.java 21  remove
# Clone132.java 22  remove
# Clone132.java 23  remove
# Clone132.java 24  remove
# Clone132.java 25  remove
# Clone132.java 26  remove
# Clone132.java 27  remove
# Clone132.java 28  remove
# Clone746.java 10  remove
# Clone746.java 12 { mutate
# Clone746.java 13  remove
# Clone746.java 14  remove
# Clone746.java 15 } mutate
# Clone746.java 23     } else if  {}
#  mutate
# Clone746.java 24 }{ mutate
# Clone746.java 25 } mutate
# Clone746.java 26  remove
# Clone746.java 27  remove
# Clone380.java 11 { mutate
# Clone380.java 12  remove
# Clone380.java 13 { mutate
# Clone380.java 14  remove
# Clone380.java 15 } mutate
# Clone380.java 16 { mutate
# Clone380.java 17  remove
# Clone380.java 18  remove
# Clone380.java 19 }{ mutate
# Clone380.java 20  remove
# Clone380.java 21  remove
# Clone380.java 22 } mutate
# Clone380.java 23 } mutate
# Clone380.java 28 ( mutate
# Clone380.java 29 ){ mutate
# Clone380.java 30 { mutate
# Clone380.java 31 { mutate
# Clone380.java 32 { mutate
# Clone380.java 33  remove
# Clone380.java 34 } mutate
# Clone380.java 35 }{ mutate
# Clone380.java 36  remove
# Clone380.java 37 }{ mutate
# Clone380.java 38  remove
# Clone380.java 39  remove
# Clone380.java 40  remove
# Clone380.java 41 } mutate
# Clone380.java 42 } mutate
# Clone380.java 43 } mutate
# Clone368.java 18 { mutate
# Clone368.java 19  remove
# Clone368.java 20 { mutate
# Clone368.java 21  remove
# Clone368.java 22 }} mutate
# Clone368.java 23  remove
# Clone368.java 25  remove
# Clone87.java 10 keyPress (); mutate
# Clone87.java 11 keyPress (); mutate
# Clone87.java 12 keyRelease (); mutate
# Clone87.java 13  remove
# Clone87.java 14 ( mutate
# Clone87.java 15 ){ mutate
# Clone87.java 16  remove
# Clone87.java 17 keyPress (); mutate
# Clone87.java 18 keyRelease (); mutate
# Clone87.java 19 } mutate
# Clone87.java 20 keyRelease (); mutate
# Clone87.java 24  remove
# Clone87.java 25  remove
# Clone87.java 26  remove
# Clone87.java 27 keyPress (); mutate
# Clone87.java 28 keyPress (); mutate
# Clone87.java 29 keyRelease (); mutate
# Clone87.java 30 keyRelease (); mutate
# Clone976.java 11  remove
# Clone976.java 12  remove
# Clone976.java 13  remove
# Clone976.java 14  remove
# Clone976.java 15  remove
# Clone976.java 16  remove
# Clone976.java 17  remove
# Clone976.java 18  remove
# Clone976.java 19  remove
# Clone976.java 20  remove
# Clone976.java 21  remove
# Clone976.java 22  remove
# Clone976.java 23  remove
# Clone976.java 24  remove
# Clone976.java 25  remove
# Clone976.java 26  remove
# Clone976.java 27  remove
# Clone976.java 28  remove
# Clone976.java 29  remove
# Clone976.java 30 { mutate
# Clone976.java 31  remove
# Clone976.java 32  remove
# Clone976.java 33 } mutate
# Clone976.java 34 ( mutate
# Clone976.java 35 ){ mutate
# Clone976.java 36  remove
# Clone976.java 37  remove
# Clone976.java 38 } mutate
# Clone976.java 39 ( mutate
# Clone976.java 40 ){ mutate
# Clone976.java 41  remove
# Clone976.java 42  remove
# Clone976.java 43 } mutate
# Clone976.java 47  remove
# Clone976.java 48  remove
# Clone976.java 49  remove
# Clone976.java 50  remove
# Clone976.java 51  remove
# Clone976.java 52  remove
# Clone976.java 53  remove
# Clone976.java 54  remove
# Clone976.java 55  remove
# Clone976.java 56  remove
# Clone976.java 57  remove
# Clone976.java 58  remove
# Clone976.java 59  remove
# Clone976.java 60  remove
# Clone976.java 61  remove
# Clone976.java 62  remove
# Clone131.java 33  remove
# Clone131.java 28  remove
# Clone131.java 29  remove
# Clone131.java 30  remove
# Clone131.java 31  remove
# Clone131.java 32  remove
# Clone592.java 35  remove
# Clone592.java 36  remove
# Clone592.java 37 { mutate
# Clone592.java 38  remove
# Clone592.java 39 { mutate
# Clone592.java 40  remove
# Clone592.java 41  remove
# Clone592.java 42  remove
# Clone592.java 43 { mutate
# Clone592.java 44  remove
# Clone592.java 45  remove
# Clone592.java 46 }{ mutate
# Clone592.java 47  remove
# Clone592.java 48 }{ mutate
# Clone592.java 49  remove
# Clone592.java 50 }{ mutate
# Clone592.java 51  remove
# Clone592.java 52 }{ mutate
# Clone592.java 53  remove
# Clone592.java 54 }{ mutate
# Clone592.java 55  remove
# Clone592.java 56 }{ mutate
# Clone592.java 57  remove
# Clone592.java 58 }{ mutate
# Clone592.java 59  remove
# Clone592.java 60 }{ mutate
# Clone592.java 61  remove
# Clone592.java 62 }{ mutate
# Clone592.java 63  remove
# Clone592.java 64 }{ mutate
# Clone592.java 65  remove
# Clone592.java 66 }{ mutate
# Clone592.java 67  remove
# Clone592.java 68 }{ mutate
# Clone592.java 69  remove
# Clone592.java 70 }{ mutate
# Clone592.java 71  remove
# Clone592.java 72 }{ mutate
# Clone592.java 73  remove
# Clone592.java 74 }{ mutate
# Clone592.java 75  remove
# Clone592.java 76 }{ mutate
# Clone592.java 77  remove
# Clone592.java 78 }{ mutate
# Clone592.java 79  remove
# Clone592.java 80 }{ mutate
# Clone592.java 81  remove
# Clone592.java 82 }{ mutate
# Clone592.java 83  remove
# Clone592.java 84 }{ mutate
# Clone592.java 85  remove
# Clone592.java 86 }{ mutate
# Clone592.java 87  remove
# Clone592.java 88 }{ mutate
# Clone592.java 89  remove
# Clone592.java 90 }{ mutate
# Clone592.java 91  remove
# Clone592.java 92 }{ mutate
# Clone592.java 93  remove
# Clone592.java 94 } mutate
# Clone592.java 95  remove
# Clone592.java 96  remove
# Clone592.java 97  remove
# Clone592.java 98 { mutate
# Clone592.java 99  remove
# Clone592.java 100  remove
# Clone592.java 101 } mutate
# Clone592.java 102 { mutate
# Clone592.java 103  remove
# Clone592.java 104  remove
# Clone592.java 105 } mutate
# Clone592.java 106 { mutate
# Clone592.java 107  remove
# Clone592.java 108  remove
# Clone592.java 109 } mutate
# Clone592.java 110 { mutate
# Clone592.java 111  remove
# Clone592.java 112  remove
# Clone592.java 113 } mutate
# Clone592.java 114 { mutate
# Clone592.java 115  remove
# Clone592.java 116  remove
# Clone592.java 117 } mutate
# Clone592.java 118 { mutate
# Clone592.java 119  remove
# Clone592.java 120  remove
# Clone592.java 121 } mutate
# Clone592.java 122 { mutate
# Clone592.java 123  remove
# Clone592.java 124  remove
# Clone592.java 125 } mutate
# Clone592.java 126 { mutate
# Clone592.java 127  remove
# Clone592.java 128  remove
# Clone592.java 129 } mutate
# Clone592.java 130 { mutate
# Clone592.java 131  remove
# Clone592.java 132  remove
# Clone592.java 133 } mutate
# Clone592.java 134 { mutate
# Clone592.java 135  remove
# Clone592.java 136  remove
# Clone592.java 137 } mutate
# Clone592.java 138 { mutate
# Clone592.java 139  remove
# Clone592.java 140  remove
# Clone592.java 141 } mutate
# Clone592.java 142 { mutate
# Clone592.java 143  remove
# Clone592.java 144  remove
# Clone592.java 145 } mutate
# Clone592.java 146 { mutate
# Clone592.java 147  remove
# Clone592.java 148  remove
# Clone592.java 149 } mutate
# Clone592.java 150 { mutate
# Clone592.java 151  remove
# Clone592.java 152  remove
# Clone592.java 153 } mutate
# Clone592.java 154 { mutate
# Clone592.java 155  remove
# Clone592.java 156  remove
# Clone592.java 157 } mutate
# Clone592.java 158 { mutate
# Clone592.java 159  remove
# Clone592.java 160  remove
# Clone592.java 161 } mutate
# Clone592.java 162 { mutate
# Clone592.java 163  remove
# Clone592.java 164  remove
# Clone592.java 165 } mutate
# Clone592.java 166 { mutate
# Clone592.java 167  remove
# Clone592.java 168  remove
# Clone592.java 169 } mutate
# Clone592.java 170 { mutate
# Clone592.java 171  remove
# Clone592.java 172  remove
# Clone592.java 173 } mutate
# Clone592.java 174 { mutate
# Clone592.java 175  remove
# Clone592.java 176  remove
# Clone592.java 177 } mutate
# Clone592.java 178 { mutate
# Clone592.java 179  remove
# Clone592.java 180  remove
# Clone592.java 181 } mutate
# Clone592.java 182 { mutate
# Clone592.java 183  remove
# Clone592.java 184  remove
# Clone592.java 185 } mutate
# Clone592.java 186 { mutate
# Clone592.java 187  remove
# Clone592.java 188  remove
# Clone592.java 189 } mutate
# Clone592.java 190 { mutate
# Clone592.java 191  remove
# Clone592.java 192  remove
# Clone592.java 193 } mutate
# Clone592.java 194  remove
# Clone592.java 195  remove
# Clone592.java 196  remove
# Clone592.java 197 { mutate
# Clone592.java 198  remove
# Clone592.java 199  remove
# Clone592.java 200 } mutate
# Clone592.java 201  remove
# Clone592.java 202 } mutate
# Clone592.java 203 } mutate
# Clone592.java 212  remove
# Clone592.java 213 { mutate
# Clone592.java 214  remove
# Clone592.java 215  remove
# Clone592.java 216 } mutate
# Clone592.java 217  remove
# Clone592.java 218  remove
# Clone592.java 219  remove
# Clone592.java 220 { mutate
# Clone592.java 221  remove
# Clone592.java 222 } mutate
# Clone109.java 37  remove
# Clone966.java 11  remove
# Clone966.java 12  remove
# Clone966.java 13  remove
# Clone966.java 14  remove
# Clone966.java 15  remove
# Clone966.java 16  remove
# Clone966.java 17  remove
# Clone966.java 18  remove
# Clone966.java 19  remove
# Clone966.java 20  remove
# Clone966.java 21  remove
# Clone966.java 22  remove
# Clone966.java 23  remove
# Clone966.java 24  remove
# Clone966.java 25  remove
# Clone966.java 26  remove
# Clone966.java 27  remove
# Clone966.java 28  remove
# Clone966.java 29  remove
# Clone966.java 30 { mutate
# Clone966.java 31  remove
# Clone966.java 32  remove
# Clone966.java 33 } mutate
# Clone966.java 34 ( mutate
# Clone966.java 35 ){ mutate
# Clone966.java 36  remove
# Clone966.java 37  remove
# Clone966.java 38 } mutate
# Clone966.java 39 ( mutate
# Clone966.java 40 ){ mutate
# Clone966.java 41  remove
# Clone966.java 42  remove
# Clone966.java 43 } mutate
# Clone966.java 47  remove
# Clone966.java 48  remove
# Clone966.java 49 { mutate
# Clone966.java 50  remove
# Clone966.java 51 } mutate
# Clone966.java 52  remove
# Clone966.java 53 { mutate
# Clone966.java 54  remove
# Clone966.java 55  remove
# Clone966.java 56  remove
# Clone966.java 57  remove
# Clone966.java 58  remove
# Clone966.java 59  remove
# Clone966.java 60  remove
# Clone966.java 61  remove
# Clone966.java 62  remove
# Clone966.java 63  remove
# Clone966.java 64  remove
# Clone966.java 65  remove
# Clone966.java 66  remove
# Clone966.java 67  remove
# Clone966.java 68  remove
# Clone966.java 69  remove
# Clone966.java 70  remove
# Clone966.java 71  remove
# Clone966.java 72  remove
# Clone966.java 73 } mutate

# %% [markdown]
# # Create mutated CSV file

# %%
# Code to build mutated CSV file

unique_file_names = {key[0] for key in mutated_line_data_dict.keys()}
error_filename = 'methoderrorsreport.csv'
# print(unique_file_names)
for filename in unique_file_names:
        original_filename = 'code-samples/' + filename
        mutated_data_folder = 'mutated-data-lx-diff-only/'
        mutated_filename = mutated_data_folder +filename + 'mutated.java'
        linecount = 0;
        method_lines = []

        with open(original_filename, 'r') as original_file, open(mutated_filename, 'w') as mutated_file, open(error_filename,'a') as error_file:
                method_lines = []
                write_to_file = []
                error_lines = []
                prev_line = ''
                for line in original_file:
                    linecount += 1
                    line = line.strip()
                    if (linecount == 9):
                        print('Line9:',line)
                    # next_line = original_file.readline().strip()
                    # print(line,next_line)
                    if(linecount>8):
                        mutated_line_data = mutated_line_data_dict.get((filename, linecount))
                        # print('m data', mutated_line_data)
                        if mutated_line_data:
                                        # Replace the line with mutated code
                                        print(mutated_line_data)
                                        mutated_code = mutated_line_data.mutatedcode
                                        mutop = mutated_line_data.mutop
                                        if(mutop == "remove"):
                                            print('do nothing')

                                        elif(mutated_code != ""):
                                            # mutated_file.write(mutated_code + '\n')
                                            # print(mutated_code + '\n')
                                            method_lines.append(mutated_code)
                        else:
                                        # Write the original method code if the line is nonempty
                                        if(line != ''):
                                            # mutated_file.write(line + '\n')
                                            # print(line)
                                            method_lines.append(line)
                                        # else:
                                        #     print('empty line')
                        if (prev_line == "}" and line == ""):
                          print('method code',method_lines)
                          for line in method_lines:
                            print(line)
                          method_code = '\n'.join(method_lines) + "\n"
                          print('code for ast',method_code)
                            # Build AST to check if it's error-free
                          try:
                                method_code_escaped = add_escape_before_double_quotes(method_code)
                                root = asts.AST.from_string(
                                    'public class { ' + method_code_escaped + '}' ,
                                    language=asts.ASTLanguage.Java,
                                    deepest=True
                                )
                                write_to_file.append(method_code + '\n')
                          except Exception as e:
                            #     # Handle AST errors or exceptions here
                                # print(root.ast_source_ranges())
                                print(f"Error processing method:", filename, method_code, e)
                                error_strings = [filename, method_code, str(e)]
                                all_errors = ', '.join(error_strings)
                                csvwriter = csv.writer(error_file)
                                csvwriter.writerow([all_errors])
                                write_to_file.append(method_code + '\n')
                          method_lines = []
                        prev_line = line

                    else:
                        write_to_file.append(line + '\n')
                for code in write_to_file:
                  mutated_file.write(code)
                mutated_file.write('}')
# Out:
# Streaming output truncated to the last 5000 lines.
# <__main__.MutatedLineData object at 0x7a48bd6d8f70>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd4775b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29c3a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29ce80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29d7e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29e380>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29ee00>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29f880>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a3c10>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a0700>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a09d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a2b30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a38e0>
# <__main__.MutatedLineData object at 0x7a48bd2a87f0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a3b20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a2c20>
# <__main__.MutatedLineData object at 0x7a48bd2a0d90>
# <__main__.MutatedLineData object at 0x7a48bd2a1360>
# <__main__.MutatedLineData object at 0x7a48bd2a39a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a1600>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29f4f0>
# <__main__.MutatedLineData object at 0x7a48bd29edd0>
# <__main__.MutatedLineData object at 0x7a48bd29e650>
# <__main__.MutatedLineData object at 0x7a48bd29ddb0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29d2d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29c850>
# method code ['private void transform (XSSFWorkbook workbookOld, HSSFWorkbook workbookNew, XSSFSheet sheetOld, HSSFSheet sheetNew) {', 'System.out.println ("transform Sheet");', '{', '}', '(', '){', '}', '(', '){', '}', '}']
# private void transform (XSSFWorkbook workbookOld, HSSFWorkbook workbookNew, XSSFSheet sheetOld, HSSFSheet sheetNew) {
# System.out.println ("transform Sheet");
# {
# }
# (
# ){
# }
# (
# ){
# }
# }
# code for ast private void transform (XSSFWorkbook workbookOld, HSSFWorkbook workbookNew, XSSFSheet sheetOld, HSSFSheet sheetNew) {
# System.out.println ("transform Sheet");
# {
# }
# (
# ){
# }
# (
# ){
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48cc2e8ee0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7aa9b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc018eb0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e6500>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11e9e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b4af0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6368c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd635300>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc24a560>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13e1a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6d9000>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2aaa40>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a83a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a8d90>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2aa290>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2ab610>
# do nothing
# method code ['private void transform (HSSFWorkbook workbookOld, XSSFWorkbook workbookNew, Integer hash, HSSFCellStyle styleOld, XSSFCellStyle styleNew) {', '}']
# private void transform (HSSFWorkbook workbookOld, XSSFWorkbook workbookNew, Integer hash, HSSFCellStyle styleOld, XSSFCellStyle styleNew) {
# }
# code for ast private void transform (HSSFWorkbook workbookOld, XSSFWorkbook workbookNew, Integer hash, HSSFCellStyle styleOld, XSSFCellStyle styleNew) {
# }
#
# Line9: public void run () {
# <__main__.MutatedLineData object at 0x7a48cc0970a0>
# <__main__.MutatedLineData object at 0x7a48cc0940d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd539450>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd53b340>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd4d8730>
# <__main__.MutatedLineData object at 0x7a48bd5389d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0949d0>
# <__main__.MutatedLineData object at 0x7a48cc096f20>
# method code ['public void run () {', 'int i = 1;', '{', 'try {', '} catch (InterruptedException e) {', 'e.printStackTrace ();', '}', 'i = i + 3;', '}', '}']
# public void run () {
# int i = 1;
# {
# try {
# } catch (InterruptedException e) {
# e.printStackTrace ();
# }
# i = i + 3;
# }
# }
# code for ast public void run () {
# int i = 1;
# {
# try {
# } catch (InterruptedException e) {
# e.printStackTrace ();
# }
# i = i + 3;
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48bd592950>
# <__main__.MutatedLineData object at 0x7a48cc0d1780>
# <__main__.MutatedLineData object at 0x7a48cc0d2560>
# <__main__.MutatedLineData object at 0x7a48bd504be0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd504580>
# <__main__.MutatedLineData object at 0x7a48bd7836a0>
# <__main__.MutatedLineData object at 0x7a48bd53ad40>
# <__main__.MutatedLineData object at 0x7a48bd782fb0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc054c10>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd744670>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd56ad70>
# <__main__.MutatedLineData object at 0x7a48bd5a2ce0>
# method code ['public synchronized void run () {', 'int i = 3;', '{', '{', '{', 'try {', '} catch (InterruptedException e) {', 'e.printStackTrace ();', '}', '}', '}', '{', 'i = i + 3;', '}', '}', '}']
# public synchronized void run () {
# int i = 3;
# {
# {
# {
# try {
# } catch (InterruptedException e) {
# e.printStackTrace ();
# }
# }
# }
# {
# i = i + 3;
# }
# }
# }
# code for ast public synchronized void run () {
# int i = 3;
# {
# {
# {
# try {
# } catch (InterruptedException e) {
# e.printStackTrace ();
# }
# }
# }
# {
# i = i + 3;
# }
# }
# }
#
# Line9: private static void verifyDirsAreEqual (Path one, Path other) throws IOException {
# method code ['private static void verifyDirsAreEqual (Path one, Path other) throws IOException {', 'Files.walkFileTree (one, new SimpleFileVisitor < Path > () {', '@Override', 'public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {', 'FileVisitResult result = super.visitFile (file, attrs);', 'Path relativize = one.relativize (file);', 'Path fileInOther = other.resolve (relativize);', 'log.debug ("=== comparing: {} to {}", file, fileInOther);', 'byte [] otherBytes = Files.readAllBytes (fileInOther);', 'byte [] thisBytes = Files.readAllBytes (file);', 'if (! Arrays.equals (otherBytes, thisTypes)) {', 'throw new AssertionFailedError (file + " is not equal to " + fileInOther);', '}', 'return result;', '}}', ');', '}']
# private static void verifyDirsAreEqual (Path one, Path other) throws IOException {
# Files.walkFileTree (one, new SimpleFileVisitor < Path > () {
# @Override
# public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {
# FileVisitResult result = super.visitFile (file, attrs);
# Path relativize = one.relativize (file);
# Path fileInOther = other.resolve (relativize);
# log.debug ("=== comparing: {} to {}", file, fileInOther);
# byte [] otherBytes = Files.readAllBytes (fileInOther);
# byte [] thisBytes = Files.readAllBytes (file);
# if (! Arrays.equals (otherBytes, thisTypes)) {
# throw new AssertionFailedError (file + " is not equal to " + fileInOther);
# }
# return result;
# }}
# );
# }
# code for ast private static void verifyDirsAreEqual (Path one, Path other) throws IOException {
# Files.walkFileTree (one, new SimpleFileVisitor < Path > () {
# @Override
# public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {
# FileVisitResult result = super.visitFile (file, attrs);
# Path relativize = one.relativize (file);
# Path fileInOther = other.resolve (relativize);
# log.debug ("=== comparing: {} to {}", file, fileInOther);
# byte [] otherBytes = Files.readAllBytes (fileInOther);
# byte [] thisBytes = Files.readAllBytes (file);
# if (! Arrays.equals (otherBytes, thisTypes)) {
# throw new AssertionFailedError (file + " is not equal to " + fileInOther);
# }
# return result;
# }}
# );
# }
#
# Error processing method: Clone376.java private static void verifyDirsAreEqual (Path one, Path other) throws IOException {
# Files.walkFileTree (one, new SimpleFileVisitor < Path > () {
# @Override
# public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {
# FileVisitResult result = super.visitFile (file, attrs);
# Path relativize = one.relativize (file);
# Path fileInOther = other.resolve (relativize);
# log.debug ("=== comparing: {} to {}", file, fileInOther);
# byte [] otherBytes = Files.readAllBytes (fileInOther);
# byte [] thisBytes = Files.readAllBytes (file);
# if (! Arrays.equals (otherBytes, thisTypes)) {
# throw new AssertionFailedError (file + " is not equal to " + fileInOther);
# }
# return result;
# }}
# );
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# <__main__.MutatedLineData object at 0x7a48cc096080>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13ef50>
# <__main__.MutatedLineData object at 0x7a48cc13cd30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13e710>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b5b40>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b4910>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b74c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6db3d0>
# do nothing
# method code ['private static void verifyDirsAreEqual (File expected, File generated) throws IOException {', 'assertTrue ("Generated Folder doesn\'t exist: " + generated, generated.exists ());', 'assertTrue ("Generated is not a folder?!?!: " + generated, generated.isDirectory ());', 'assertTrue ("Expected Folder doesn\'t exist: " + expected, expected.exists ());', 'assertTrue ("Expected is not a folder?!?!: " + expected, expected.isDirectory ());', 'Files.walkFileTree (expected.toPath (), new SimpleFileVisitor < Path > () {', '{', '}@Override', 'public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {', 'FileVisitResult result = super.visitFile (file, attrs);', 'Path relativize = expected.toPath ().relativize (file);', 'File fileInOther = generated.toPath ().resolve (relativize).toFile ();', 'log.debug ("=== comparing: " + file + " to " + fileInOther);', 'String expectedContents = FileUtils.readFileToString (file.toFile ());', 'String generatedContents = FileUtils.readFileToString (fileInOther);', 'assertEquals ("(" + fileInOther + ")  csv standard doesn\'t match expected (" + file + ")!", expectedContents, generatedContents);', 'return result;', '}}', ');', '}']
# private static void verifyDirsAreEqual (File expected, File generated) throws IOException {
# assertTrue ("Generated Folder doesn't exist: " + generated, generated.exists ());
# assertTrue ("Generated is not a folder?!?!: " + generated, generated.isDirectory ());
# assertTrue ("Expected Folder doesn't exist: " + expected, expected.exists ());
# assertTrue ("Expected is not a folder?!?!: " + expected, expected.isDirectory ());
# Files.walkFileTree (expected.toPath (), new SimpleFileVisitor < Path > () {
# {
# }@Override
# public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {
# FileVisitResult result = super.visitFile (file, attrs);
# Path relativize = expected.toPath ().relativize (file);
# File fileInOther = generated.toPath ().resolve (relativize).toFile ();
# log.debug ("=== comparing: " + file + " to " + fileInOther);
# String expectedContents = FileUtils.readFileToString (file.toFile ());
# String generatedContents = FileUtils.readFileToString (fileInOther);
# assertEquals ("(" + fileInOther + ")  csv standard doesn't match expected (" + file + ")!", expectedContents, generatedContents);
# return result;
# }}
# );
# }
# code for ast private static void verifyDirsAreEqual (File expected, File generated) throws IOException {
# assertTrue ("Generated Folder doesn't exist: " + generated, generated.exists ());
# assertTrue ("Generated is not a folder?!?!: " + generated, generated.isDirectory ());
# assertTrue ("Expected Folder doesn't exist: " + expected, expected.exists ());
# assertTrue ("Expected is not a folder?!?!: " + expected, expected.isDirectory ());
# Files.walkFileTree (expected.toPath (), new SimpleFileVisitor < Path > () {
# {
# }@Override
# public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {
# FileVisitResult result = super.visitFile (file, attrs);
# Path relativize = expected.toPath ().relativize (file);
# File fileInOther = generated.toPath ().resolve (relativize).toFile ();
# log.debug ("=== comparing: " + file + " to " + fileInOther);
# String expectedContents = FileUtils.readFileToString (file.toFile ());
# String generatedContents = FileUtils.readFileToString (fileInOther);
# assertEquals ("(" + fileInOther + ")  csv standard doesn't match expected (" + file + ")!", expectedContents, generatedContents);
# return result;
# }}
# );
# }
#
# Error processing method: Clone376.java private static void verifyDirsAreEqual (File expected, File generated) throws IOException {
# assertTrue ("Generated Folder doesn't exist: " + generated, generated.exists ());
# assertTrue ("Generated is not a folder?!?!: " + generated, generated.isDirectory ());
# assertTrue ("Expected Folder doesn't exist: " + expected, expected.exists ());
# assertTrue ("Expected is not a folder?!?!: " + expected, expected.isDirectory ());
# Files.walkFileTree (expected.toPath (), new SimpleFileVisitor < Path > () {
# {
# }@Override
# public FileVisitResult visitFile (Path file, BasicFileAttributes attrs) throws IOException {
# FileVisitResult result = super.visitFile (file, attrs);
# Path relativize = expected.toPath ().relativize (file);
# File fileInOther = generated.toPath ().resolve (relativize).toFile ();
# log.debug ("=== comparing: " + file + " to " + fileInOther);
# String expectedContents = FileUtils.readFileToString (file.toFile ());
# String generatedContents = FileUtils.readFileToString (fileInOther);
# assertEquals ("(" + fileInOther + ")  csv standard doesn't match expected (" + file + ")!", expectedContents, generatedContents);
# return result;
# }}
# );
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# Line9: public static void main (String...args) {
# <__main__.MutatedLineData object at 0x7a48cc13d9f0>
# <__main__.MutatedLineData object at 0x7a48cc018190>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc01bdf0>
# <__main__.MutatedLineData object at 0x7a48cc019a80>
# <__main__.MutatedLineData object at 0x7a48cc01b190>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd54c520>
# <__main__.MutatedLineData object at 0x7a48bd568490>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd744e20>
# <__main__.MutatedLineData object at 0x7a48cc0572b0>
# <__main__.MutatedLineData object at 0x7a48cc0554b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7827d0>
# <__main__.MutatedLineData object at 0x7a48bd506110>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d35b0>
# <__main__.MutatedLineData object at 0x7a48cc0d0250>
# <__main__.MutatedLineData object at 0x7a48cc0d3b80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc095b40>
# <__main__.MutatedLineData object at 0x7a48cc096e60>
# do nothing
# method code ['public static void main (String...args) {', 'processor = new DefaultProcessor ();', 'long [] values = new long [] {0, 4, 10, 12, 100, 108, 299, 1000, 1003, 2040, 45213, 100000, 100005, 100010, 202020, 202022, 999999, 1000000, 1000001, 10000000, 10000007, 99999999, Long.MAX_VALUE, Long.MIN_VALUE};', 'String [] strValues = new String [] {"0001.2", "3.141592"};', '{', '}', '{', '}', '(', '){', '}', '(', '){', '}', '}']
# public static void main (String...args) {
# processor = new DefaultProcessor ();
# long [] values = new long [] {0, 4, 10, 12, 100, 108, 299, 1000, 1003, 2040, 45213, 100000, 100005, 100010, 202020, 202022, 999999, 1000000, 1000001, 10000000, 10000007, 99999999, Long.MAX_VALUE, Long.MIN_VALUE};
# String [] strValues = new String [] {"0001.2", "3.141592"};
# {
# }
# {
# }
# (
# ){
# }
# (
# ){
# }
# }
# code for ast public static void main (String...args) {
# processor = new DefaultProcessor ();
# long [] values = new long [] {0, 4, 10, 12, 100, 108, 299, 1000, 1003, 2040, 45213, 100000, 100005, 100010, 202020, 202022, 999999, 1000000, 1000001, 10000000, 10000007, 99999999, Long.MAX_VALUE, Long.MIN_VALUE};
# String [] strValues = new String [] {"0001.2", "3.141592"};
# {
# }
# {
# }
# (
# ){
# }
# (
# ){
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48cc094a90>
# <__main__.MutatedLineData object at 0x7a48bd53abf0>
# <__main__.MutatedLineData object at 0x7a48bd5388e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc22cbb0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc22f880>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6680a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd66bd00>
# <__main__.MutatedLineData object at 0x7a48bd66a770>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd669990>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd668eb0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b55a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b4670>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b6140>
# <__main__.MutatedLineData object at 0x7a48bd6b6860>
# <__main__.MutatedLineData object at 0x7a48bd6b6f80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b7a60>
# do nothing
# method code ['public static void main (String [] args) {', 'System.out.println ("Enter Number to convert into words");', 'Scanner sc = new Scanner (System.in);', 'long num = sc.nextInt ();', 'int rem = 0;', 'int i = 0;', '{', '{', '}{', '}', '}', '}']
# public static void main (String [] args) {
# System.out.println ("Enter Number to convert into words");
# Scanner sc = new Scanner (System.in);
# long num = sc.nextInt ();
# int rem = 0;
# int i = 0;
# {
# {
# }{
# }
# }
# }
# code for ast public static void main (String [] args) {
# System.out.println ("Enter Number to convert into words");
# Scanner sc = new Scanner (System.in);
# long num = sc.nextInt ();
# int rem = 0;
# int i = 0;
# {
# {
# }{
# }
# }
# }
#
# Line9: protected void paintComponent (Graphics g) {
# <__main__.MutatedLineData object at 0x7a48bd71caf0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7df550>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d2470>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d1c60>
# <__main__.MutatedLineData object at 0x7a48cc0d1720>
# <__main__.MutatedLineData object at 0x7a48bd7dc910>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd475fc0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5b0e80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d0e80>
# <__main__.MutatedLineData object at 0x7a48cc0d0790>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d3a00>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d34f0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd464730>
# <__main__.MutatedLineData object at 0x7a48bd505e70>
# <__main__.MutatedLineData object at 0x7a48bd507e20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5040d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5916c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc096560>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0972e0>
# <__main__.MutatedLineData object at 0x7a48cc097ca0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0951b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc094610>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd539870>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd538220>
# <__main__.MutatedLineData object at 0x7a48bd53b0a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd54c790>
# <__main__.MutatedLineData object at 0x7a48bd54ed40>
# <__main__.MutatedLineData object at 0x7a48bd54f6d0>
# <__main__.MutatedLineData object at 0x7a48bd783f40>
# <__main__.MutatedLineData object at 0x7a48bd781300>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd783640>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5a3bb0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5a0a90>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd746bf0>
# <__main__.MutatedLineData object at 0x7a48bd744f40>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5683d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd569ab0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5682e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0541f0>
# <__main__.MutatedLineData object at 0x7a48cc0549d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0554e0>
# <__main__.MutatedLineData object at 0x7a48cc055d20>
# <__main__.MutatedLineData object at 0x7a48cc056500>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc056f80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc057af0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc01bd00>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc054130>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc057ac0>
# <__main__.MutatedLineData object at 0x7a48cc057580>
# <__main__.MutatedLineData object at 0x7a48cc056c20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0561a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0555a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc054970>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd42fd30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd568760>
# <__main__.MutatedLineData object at 0x7a48bd569750>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd747070>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd746680>
# <__main__.MutatedLineData object at 0x7a48bd747e50>
# <__main__.MutatedLineData object at 0x7a48bd5a02b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd745d80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd747f40>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7470d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd569840>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd56a320>
# method code ['protected void paintComponent (Graphics g) {', 'super.paintComponent (g);', 'Graphics2D g2 = (Graphics2D) g;', 'g2.setRenderingHint (RenderingHints.KEY_ANTIALIASING, RenderingHints.VALUE_ANTIALIAS_ON);', '(', '){', '}', '(', '){', '{', 'FontMetrics metrics = g2.getFontMetrics ();', 'int labelWidth = metrics.stringWidth (yLabel);', 'g2.drawString (yLabel, x0 - labelWidth - 5, y0 + (metrics.getHeight () / 2) - 3);', '}', '}', '(', '){', '{', '{', 'FontMetrics metrics = g2.getFontMetrics ();', 'int labelWidth = metrics.stringWidth (xLabel);', 'g2.drawString (xLabel, x0 - labelWidth / 2, y0 + metrics.getHeight () + 3);', '}', '}', '}', '(', '){', '}', '(', '){', '}', '}']
# protected void paintComponent (Graphics g) {
# super.paintComponent (g);
# Graphics2D g2 = (Graphics2D) g;
# g2.setRenderingHint (RenderingHints.KEY_ANTIALIASING, RenderingHints.VALUE_ANTIALIAS_ON);
# (
# ){
# }
# (
# ){
# {
# FontMetrics metrics = g2.getFontMetrics ();
# int labelWidth = metrics.stringWidth (yLabel);
# g2.drawString (yLabel, x0 - labelWidth - 5, y0 + (metrics.getHeight () / 2) - 3);
# }
# }
# (
# ){
# {
# {
# FontMetrics metrics = g2.getFontMetrics ();
# int labelWidth = metrics.stringWidth (xLabel);
# g2.drawString (xLabel, x0 - labelWidth / 2, y0 + metrics.getHeight () + 3);
# }
# }
# }
# (
# ){
# }
# (
# ){
# }
# }
# code for ast protected void paintComponent (Graphics g) {
# super.paintComponent (g);
# Graphics2D g2 = (Graphics2D) g;
# g2.setRenderingHint (RenderingHints.KEY_ANTIALIASING, RenderingHints.VALUE_ANTIALIAS_ON);
# (
# ){
# }
# (
# ){
# {
# FontMetrics metrics = g2.getFontMetrics ();
# int labelWidth = metrics.stringWidth (yLabel);
# g2.drawString (yLabel, x0 - labelWidth - 5, y0 + (metrics.getHeight () / 2) - 3);
# }
# }
# (
# ){
# {
# {
# FontMetrics metrics = g2.getFontMetrics ();
# int labelWidth = metrics.stringWidth (xLabel);
# g2.drawString (xLabel, x0 - labelWidth / 2, y0 + metrics.getHeight () + 3);
# }
# }
# }
# (
# ){
# }
# (
# ){
# }
# }
#
# method code ['public void paintComponent (Graphics g) {', 'super.paintComponent (g);', 'Graphics2D gg = (Graphics2D) g;', 'gg.setRenderingHint (RenderingHints.KEY_ANTIALIASING, RenderingHints.VALUE_ANTIALIAS_ON);', 'Font font = new Font ("Arial", Font.PLAIN, 15);', 'String string = "Distance (m)";', 'FontMetrics metrics = g.getFontMetrics (font);', 'int width = metrics.stringWidth (string);', 'int height = metrics.getHeight ();', 'gg.setFont (font);', 'gg.drawString (string, (getWidth () - width) / 2, 11);', '}']
# public void paintComponent (Graphics g) {
# super.paintComponent (g);
# Graphics2D gg = (Graphics2D) g;
# gg.setRenderingHint (RenderingHints.KEY_ANTIALIASING, RenderingHints.VALUE_ANTIALIAS_ON);
# Font font = new Font ("Arial", Font.PLAIN, 15);
# String string = "Distance (m)";
# FontMetrics metrics = g.getFontMetrics (font);
# int width = metrics.stringWidth (string);
# int height = metrics.getHeight ();
# gg.setFont (font);
# gg.drawString (string, (getWidth () - width) / 2, 11);
# }
# code for ast public void paintComponent (Graphics g) {
# super.paintComponent (g);
# Graphics2D gg = (Graphics2D) g;
# gg.setRenderingHint (RenderingHints.KEY_ANTIALIASING, RenderingHints.VALUE_ANTIALIAS_ON);
# Font font = new Font ("Arial", Font.PLAIN, 15);
# String string = "Distance (m)";
# FontMetrics metrics = g.getFontMetrics (font);
# int width = metrics.stringWidth (string);
# int height = metrics.getHeight ();
# gg.setFont (font);
# gg.drawString (string, (getWidth () - width) / 2, 11);
# }
#
# Line9: public void actionPerformed (ActionEvent e) {
# <__main__.MutatedLineData object at 0x7a48bd7dd330>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7df310>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5904c0>
# <__main__.MutatedLineData object at 0x7a48bd590040>
# <__main__.MutatedLineData object at 0x7a48bd71e2f0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5b0370>
# <__main__.MutatedLineData object at 0x7a48bd5b3d90>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd507dc0>
# <__main__.MutatedLineData object at 0x7a48bd505330>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5b1000>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd71f460>
# <__main__.MutatedLineData object at 0x7a48bd591a50>
# <__main__.MutatedLineData object at 0x7a48bd592f20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5908e0>
# <__main__.MutatedLineData object at 0x7a48bd591ed0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd71cfa0>
# <__main__.MutatedLineData object at 0x7a48bd5e01f0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5b0190>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7de9b0>
# method code ['public void actionPerformed (ActionEvent e) {', '{', '{', '{', '}}', '}{', '{', '{', '}}', '}', '}']
# public void actionPerformed (ActionEvent e) {
# {
# {
# {
# }}
# }{
# {
# {
# }}
# }
# }
# code for ast public void actionPerformed (ActionEvent e) {
# {
# {
# {
# }}
# }{
# {
# {
# }}
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48bd7dda50>
# <__main__.MutatedLineData object at 0x7a48bd477490>
# <__main__.MutatedLineData object at 0x7a48bd7dca90>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5b03d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5e0850>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd71dd80>
# <__main__.MutatedLineData object at 0x7a48bd591d20>
# <__main__.MutatedLineData object at 0x7a48bd505000>
# do nothing
# method code ['public void actionPerformed (ActionEvent e) {', 'System.out.println ();', 'System.out.println ("Close Dialogs");', '{', '{', '}', '}', '}']
# public void actionPerformed (ActionEvent e) {
# System.out.println ();
# System.out.println ("Close Dialogs");
# {
# {
# }
# }
# }
# code for ast public void actionPerformed (ActionEvent e) {
# System.out.println ();
# System.out.println ("Close Dialogs");
# {
# {
# }
# }
# }
#
# Line9: public static void main (String [] args) throws Exception {
# <__main__.MutatedLineData object at 0x7a48cc11f160>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11f2e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11cb20>
# do nothing
# method code ['public static void main (String [] args) throws Exception {', 'ObservableList < Integer > olist = new ObservableList < > ();', 'olist.getObservable ().subscribe (System.out :: println);', 'olist.add (1);', 'olist.add (2);', '}']
# public static void main (String [] args) throws Exception {
# ObservableList < Integer > olist = new ObservableList < > ();
# olist.getObservable ().subscribe (System.out :: println);
# olist.add (1);
# olist.add (2);
# }
# code for ast public static void main (String [] args) throws Exception {
# ObservableList < Integer > olist = new ObservableList < > ();
# olist.getObservable ().subscribe (System.out :: println);
# olist.add (1);
# olist.add (2);
# }
#
# Error processing method: Clone752.java public static void main (String [] args) throws Exception {
# ObservableList < Integer > olist = new ObservableList < > ();
# olist.getObservable ().subscribe (System.out :: println);
# olist.add (1);
# olist.add (2);
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# <__main__.MutatedLineData object at 0x7a48cc11ece0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6dbee0>
# <__main__.MutatedLineData object at 0x7a48bd6db700>
# <__main__.MutatedLineData object at 0x7a48bd6dac20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e7970>
# method code ['public static void main (String [] args) {', 'List < Integer > initialNumbers = new ArrayList < Integer > ();', 'initialNumbers.add (1);', 'initialNumbers.add (2);', 'Observable < Integer > observableInitial = Observable.from (initialNumbers);', 'Observable < Integer > source = Observable.merge (observableInitial, subject);', 'source.subscribe (System.out :: println);', '(', '){', '}', '}']
# public static void main (String [] args) {
# List < Integer > initialNumbers = new ArrayList < Integer > ();
# initialNumbers.add (1);
# initialNumbers.add (2);
# Observable < Integer > observableInitial = Observable.from (initialNumbers);
# Observable < Integer > source = Observable.merge (observableInitial, subject);
# source.subscribe (System.out :: println);
# (
# ){
# }
# }
# code for ast public static void main (String [] args) {
# List < Integer > initialNumbers = new ArrayList < Integer > ();
# initialNumbers.add (1);
# initialNumbers.add (2);
# Observable < Integer > observableInitial = Observable.from (initialNumbers);
# Observable < Integer > source = Observable.merge (observableInitial, subject);
# source.subscribe (System.out :: println);
# (
# ){
# }
# }
#
# Line9: public void run () {
# <__main__.MutatedLineData object at 0x7a48cc0d23b0>
# do nothing
# method code ['public void run () {', 'try {', 'Thread.sleep (500);', 'Thread.sleep (500);', 'count = 0;', 'Thread.sleep (750);', '} catch (Exception e) {', 'System.out.println (e);', '}', '}']
# public void run () {
# try {
# Thread.sleep (500);
# Thread.sleep (500);
# count = 0;
# Thread.sleep (750);
# } catch (Exception e) {
# System.out.println (e);
# }
# }
# code for ast public void run () {
# try {
# Thread.sleep (500);
# Thread.sleep (500);
# count = 0;
# Thread.sleep (750);
# } catch (Exception e) {
# System.out.println (e);
# }
# }
#
# method code ['public void run () {', 'try {', 'runs = true;', 'if (noColor < 2) {', 'noColor ++;', 'changeBtnForegroung (clr [noColor]);', '} else {', 'noColor = 0;', 'changeBtnForegroung (clr [noColor]);', '}', 'changeBtnMargin (new Insets (initMargin.top, initMargin.left + 10, initMargin.bottom, initMargin.right - 10));', 'border = new EmptyBorder (0, 5, 10, 5);', 'changePnlBorder (border);', 'Thread.sleep (100);', 'changeBtnMargin (new Insets (initMargin.top, initMargin.left - 10, initMargin.bottom, initMargin.right + 10));', 'border = new EmptyBorder (0, 0, 10, 10);', 'changePnlBorder (border);', 'Thread.sleep (100);', 'changeBtnMargin (new Insets (initMargin.top, initMargin.left + 10, initMargin.bottom, initMargin.right - 10));', 'border = new EmptyBorder (5, 10, 5, 0);', 'changePnlBorder (border);', 'Thread.sleep (100);', 'changeBtnMargin (new Insets (initMargin.top, initMargin.left - 10, initMargin.bottom, initMargin.right + 10));', 'border = new EmptyBorder (10, 10, 0, 0);', 'changePnlBorder (border);', 'Thread.sleep (100);', 'changeBtnMargin (new Insets (initMargin.top, initMargin.left, initMargin.bottom, initMargin.right));', 'border = new EmptyBorder (5, 5, 5, 5);', 'changePnlBorder (border);', 'Thread.sleep (100);', 'count ++;', '} catch (Exception e) {', 'System.out.println (e);', '}', '}']
# public void run () {
# try {
# runs = true;
# if (noColor < 2) {
# noColor ++;
# changeBtnForegroung (clr [noColor]);
# } else {
# noColor = 0;
# changeBtnForegroung (clr [noColor]);
# }
# changeBtnMargin (new Insets (initMargin.top, initMargin.left + 10, initMargin.bottom, initMargin.right - 10));
# border = new EmptyBorder (0, 5, 10, 5);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left - 10, initMargin.bottom, initMargin.right + 10));
# border = new EmptyBorder (0, 0, 10, 10);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left + 10, initMargin.bottom, initMargin.right - 10));
# border = new EmptyBorder (5, 10, 5, 0);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left - 10, initMargin.bottom, initMargin.right + 10));
# border = new EmptyBorder (10, 10, 0, 0);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left, initMargin.bottom, initMargin.right));
# border = new EmptyBorder (5, 5, 5, 5);
# changePnlBorder (border);
# Thread.sleep (100);
# count ++;
# } catch (Exception e) {
# System.out.println (e);
# }
# }
# code for ast public void run () {
# try {
# runs = true;
# if (noColor < 2) {
# noColor ++;
# changeBtnForegroung (clr [noColor]);
# } else {
# noColor = 0;
# changeBtnForegroung (clr [noColor]);
# }
# changeBtnMargin (new Insets (initMargin.top, initMargin.left + 10, initMargin.bottom, initMargin.right - 10));
# border = new EmptyBorder (0, 5, 10, 5);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left - 10, initMargin.bottom, initMargin.right + 10));
# border = new EmptyBorder (0, 0, 10, 10);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left + 10, initMargin.bottom, initMargin.right - 10));
# border = new EmptyBorder (5, 10, 5, 0);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left - 10, initMargin.bottom, initMargin.right + 10));
# border = new EmptyBorder (10, 10, 0, 0);
# changePnlBorder (border);
# Thread.sleep (100);
# changeBtnMargin (new Insets (initMargin.top, initMargin.left, initMargin.bottom, initMargin.right));
# border = new EmptyBorder (5, 5, 5, 5);
# changePnlBorder (border);
# Thread.sleep (100);
# count ++;
# } catch (Exception e) {
# System.out.println (e);
# }
# }
#
# Line9: public void serialize (Object value, JsonGenerator jgen, SerializerProvider provider) throws IOException {
# <__main__.MutatedLineData object at 0x7a48cc0d0340>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d1600>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5caf20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7dd780>
# do nothing
# method code ['public void serialize (Object value, JsonGenerator jgen, SerializerProvider provider) throws IOException {', 'jgen.writeStartObject ();', 'jgen.writeObjectField ("my_extra_field", "some data");', 'jgen.writeEndObject ();', '}']
# public void serialize (Object value, JsonGenerator jgen, SerializerProvider provider) throws IOException {
# jgen.writeStartObject ();
# jgen.writeObjectField ("my_extra_field", "some data");
# jgen.writeEndObject ();
# }
# code for ast public void serialize (Object value, JsonGenerator jgen, SerializerProvider provider) throws IOException {
# jgen.writeStartObject ();
# jgen.writeObjectField ("my_extra_field", "some data");
# jgen.writeEndObject ();
# }
#
# Error processing method: Clone18.java public void serialize (Object value, JsonGenerator jgen, SerializerProvider provider) throws IOException {
# jgen.writeStartObject ();
# jgen.writeObjectField ("my_extra_field", "some data");
# jgen.writeEndObject ();
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# method code ['@Override', 'public void serialize (Test value, JsonGenerator jgen, SerializerProvider provider) throws IOException, JsonProcessingException {', 'jgen.writeStartObject ();', 'Field [] fields = value.getClass ().getDeclaredFields ();', 'for (Field field : fields) {', 'try {', 'jgen.writeObjectField (field.getName (), field.get (value));', '} catch (IllegalArgumentException | IllegalAccessException e) {', 'e.printStackTrace ();', '}', '}', 'jgen.writeObjectField ("extra_field", "whatever_value");', 'jgen.writeEndObject ();', '}']
# @Override
# public void serialize (Test value, JsonGenerator jgen, SerializerProvider provider) throws IOException, JsonProcessingException {
# jgen.writeStartObject ();
# Field [] fields = value.getClass ().getDeclaredFields ();
# for (Field field : fields) {
# try {
# jgen.writeObjectField (field.getName (), field.get (value));
# } catch (IllegalArgumentException | IllegalAccessException e) {
# e.printStackTrace ();
# }
# }
# jgen.writeObjectField ("extra_field", "whatever_value");
# jgen.writeEndObject ();
# }
# code for ast @Override
# public void serialize (Test value, JsonGenerator jgen, SerializerProvider provider) throws IOException, JsonProcessingException {
# jgen.writeStartObject ();
# Field [] fields = value.getClass ().getDeclaredFields ();
# for (Field field : fields) {
# try {
# jgen.writeObjectField (field.getName (), field.get (value));
# } catch (IllegalArgumentException | IllegalAccessException e) {
# e.printStackTrace ();
# }
# }
# jgen.writeObjectField ("extra_field", "whatever_value");
# jgen.writeEndObject ();
# }
#
# Error processing method: Clone18.java @Override
# public void serialize (Test value, JsonGenerator jgen, SerializerProvider provider) throws IOException, JsonProcessingException {
# jgen.writeStartObject ();
# Field [] fields = value.getClass ().getDeclaredFields ();
# for (Field field : fields) {
# try {
# jgen.writeObjectField (field.getName (), field.get (value));
# } catch (IllegalArgumentException | IllegalAccessException e) {
# e.printStackTrace ();
# }
# }
# jgen.writeObjectField ("extra_field", "whatever_value");
# jgen.writeEndObject ();
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# Line9: public MyViewHolder (View view) {
# <__main__.MutatedLineData object at 0x7a48cc01b0a0>
# <__main__.MutatedLineData object at 0x7a48cc097a60>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13cbe0>
# <__main__.MutatedLineData object at 0x7a48cc13f580>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13f5e0>
# <__main__.MutatedLineData object at 0x7a48bd6b6cb0>
# method code ['public MyViewHolder (View view) {', 'super (view);', '{(', '{', '}', '})', '}']
# public MyViewHolder (View view) {
# super (view);
# {(
# {
# }
# })
# }
# code for ast public MyViewHolder (View view) {
# super (view);
# {(
# {
# }
# })
# }
#
# <__main__.MutatedLineData object at 0x7a48bd6b5150>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd337d00>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd337040>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd336680>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd335a20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6b77f0>
# do nothing
# method code ['public MyViewHolder (View itemView) {', 'super (itemView);', '}']
# public MyViewHolder (View itemView) {
# super (itemView);
# }
# code for ast public MyViewHolder (View itemView) {
# super (itemView);
# }
#
# Line9: public static void main (String [] args) {
# <__main__.MutatedLineData object at 0x7a48bd634c10>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd635630>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd782350>
# <__main__.MutatedLineData object at 0x7a48cc057760>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd54e770>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd66af20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd3356c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd3361d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd336dd0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd337c70>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd3346d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd267eb0>
# method code ['public static void main (String [] args) {', 'int n = 0;', 'Scanner s = new Scanner (System.in);', 'System.out.print ("Enter an integer number: ");', '{', '}', '}']
# public static void main (String [] args) {
# int n = 0;
# Scanner s = new Scanner (System.in);
# System.out.print ("Enter an integer number: ");
# {
# }
# }
# code for ast public static void main (String [] args) {
# int n = 0;
# Scanner s = new Scanner (System.in);
# System.out.print ("Enter an integer number: ");
# {
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48bd2659c0>
# <__main__.MutatedLineData object at 0x7a48bd2660e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2669e0>
# <__main__.MutatedLineData object at 0x7a48bd264d90>
# <__main__.MutatedLineData object at 0x7a48bd264670>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd266e90>
# <__main__.MutatedLineData object at 0x7a48bd2674f0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd284670>
# <__main__.MutatedLineData object at 0x7a48bd284c70>
# <__main__.MutatedLineData object at 0x7a48bd285270>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd285b10>
# <__main__.MutatedLineData object at 0x7a48bd286170>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd284550>
# <__main__.MutatedLineData object at 0x7a48bd286a70>
# <__main__.MutatedLineData object at 0x7a48bd287010>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2877f0>
# <__main__.MutatedLineData object at 0x7a48bd287d90>
# do nothing
# method code ['public static void main (String...args) {', 'processor = new DefaultProcessor ();', 'long [] values = new long [] {0, 4, 10, 12, 100, 108, 299, 1000, 1003, 2040, 45213, 100000, 100005, 100010, 202020, 202022, 999999, 1000000, 1000001, 10000000, 10000007, 99999999, Long.MAX_VALUE, Long.MIN_VALUE};', 'String [] strValues = new String [] {"0", "1.30", "0001.00", "3.141592"};', '{', '}', '{', '}', '(', '){', '}', '(', '){', '}', '}']
# public static void main (String...args) {
# processor = new DefaultProcessor ();
# long [] values = new long [] {0, 4, 10, 12, 100, 108, 299, 1000, 1003, 2040, 45213, 100000, 100005, 100010, 202020, 202022, 999999, 1000000, 1000001, 10000000, 10000007, 99999999, Long.MAX_VALUE, Long.MIN_VALUE};
# String [] strValues = new String [] {"0", "1.30", "0001.00", "3.141592"};
# {
# }
# {
# }
# (
# ){
# }
# (
# ){
# }
# }
# code for ast public static void main (String...args) {
# processor = new DefaultProcessor ();
# long [] values = new long [] {0, 4, 10, 12, 100, 108, 299, 1000, 1003, 2040, 45213, 100000, 100005, 100010, 202020, 202022, 999999, 1000000, 1000001, 10000000, 10000007, 99999999, Long.MAX_VALUE, Long.MIN_VALUE};
# String [] strValues = new String [] {"0", "1.30", "0001.00", "3.141592"};
# {
# }
# {
# }
# (
# ){
# }
# (
# ){
# }
# }
#
# Line9: public Command deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# <__main__.MutatedLineData object at 0x7a48cc13ca00>
# <__main__.MutatedLineData object at 0x7a48cc11fd60>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11d450>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11c970>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e6e30>
# <__main__.MutatedLineData object at 0x7a48cc1e5600>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e66e0>
# method code ['public Command deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {', '{', 'JsonObject commandObject = json.getAsJsonObject ();', 'JsonElement commandTypeElement = commandObject.get (commandElementName);', '}{', '}', '}']
# public Command deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# {
# JsonObject commandObject = json.getAsJsonObject ();
# JsonElement commandTypeElement = commandObject.get (commandElementName);
# }{
# }
# }
# code for ast public Command deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# {
# JsonObject commandObject = json.getAsJsonObject ();
# JsonElement commandTypeElement = commandObject.get (commandElementName);
# }{
# }
# }
#
# Error processing method: Clone198.java public Command deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# {
# JsonObject commandObject = json.getAsJsonObject ();
# JsonElement commandTypeElement = commandObject.get (commandElementName);
# }{
# }
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# <__main__.MutatedLineData object at 0x7a48cc11f400>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11e260>
# <__main__.MutatedLineData object at 0x7a48cc11e5c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e4b80>
# <__main__.MutatedLineData object at 0x7a48cc1e7b80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e4d60>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6daaa0>
# <__main__.MutatedLineData object at 0x7a48bd6db5e0>
# do nothing
# method code ['public IAnimal deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {', 'JsonObject jsonObject = json.getAsJsonObject ();', 'JsonPrimitive prim = (JsonPrimitive) jsonObject.get (CLASSNAME);', 'String className = prim.getAsString ();', '{', '}{', '}', '}']
# public IAnimal deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# JsonObject jsonObject = json.getAsJsonObject ();
# JsonPrimitive prim = (JsonPrimitive) jsonObject.get (CLASSNAME);
# String className = prim.getAsString ();
# {
# }{
# }
# }
# code for ast public IAnimal deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# JsonObject jsonObject = json.getAsJsonObject ();
# JsonPrimitive prim = (JsonPrimitive) jsonObject.get (CLASSNAME);
# String className = prim.getAsString ();
# {
# }{
# }
# }
#
# Error processing method: Clone198.java public IAnimal deserialize (JsonElement json, Type typeOfT, JsonDeserializationContext context) throws JsonParseException {
# JsonObject jsonObject = json.getAsJsonObject ();
# JsonPrimitive prim = (JsonPrimitive) jsonObject.get (CLASSNAME);
# String className = prim.getAsString ();
# {
# }{
# }
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# Line9: public synchronized void add (M msg) {
# <__main__.MutatedLineData object at 0x7a48cc11c250>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5071f0>
# <__main__.MutatedLineData object at 0x7a48bd6371c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd636ef0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc054ee0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc055cc0>
# <__main__.MutatedLineData object at 0x7a48bd6358d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6351e0>
# do nothing
# method code ['public synchronized void add (M msg) {', '{', '}', '}']
# public synchronized void add (M msg) {
# {
# }
# }
# code for ast public synchronized void add (M msg) {
# {
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48cc11c730>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11ee30>
# <__main__.MutatedLineData object at 0x7a48cc0d2290>
# <__main__.MutatedLineData object at 0x7a48bd56b0a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e4940>
# <__main__.MutatedLineData object at 0x7a48cc22da20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6d8760>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6dac50>
# ...
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd637e50>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc019150>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd634d00>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd6369e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd635b40>
# do nothing
# method code ['@Override', 'public void start (Stage stage) throws Exception {', 'Scene scene = new Scene (shadowPane);', 'stage.setScene (scene);', 'stage.show ();', '}']
# @Override
# public void start (Stage stage) throws Exception {
# Scene scene = new Scene (shadowPane);
# stage.setScene (scene);
# stage.show ();
# }
# code for ast @Override
# public void start (Stage stage) throws Exception {
# Scene scene = new Scene (shadowPane);
# stage.setScene (scene);
# stage.show ();
# }
#
# Error processing method: Clone892.java @Override
# public void start (Stage stage) throws Exception {
# Scene scene = new Scene (shadowPane);
# stage.setScene (scene);
# stage.show ();
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# <__main__.MutatedLineData object at 0x7a48bd637010>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11d2a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11f4c0>
# <__main__.MutatedLineData object at 0x7a48cc11fb50>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc11dba0>
# <__main__.MutatedLineData object at 0x7a48cc1e4e20>
# <__main__.MutatedLineData object at 0x7a48cc1e7010>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc1e5660>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc22e1a0>
# <__main__.MutatedLineData object at 0x7a48cc22e200>
# <__main__.MutatedLineData object at 0x7a48bd6d8bb0>
# <__main__.MutatedLineData object at 0x7a48bd6dba00>
# do nothing
# method code ['public void start (final Stage primaryStage) {', '{(', '{', '{', '}', '}}', ')', 'primaryStage.setTitle ("Modal Confirm Example");', 'primaryStage.setScene (new Scene (webView));', 'primaryStage.show ();', '}']
# public void start (final Stage primaryStage) {
# {(
# {
# {
# }
# }}
# )
# primaryStage.setTitle ("Modal Confirm Example");
# primaryStage.setScene (new Scene (webView));
# primaryStage.show ();
# }
# code for ast public void start (final Stage primaryStage) {
# {(
# {
# {
# }
# }}
# )
# primaryStage.setTitle ("Modal Confirm Example");
# primaryStage.setScene (new Scene (webView));
# primaryStage.show ();
# }
#
# Line9: public void actionPerformed (ActionEvent arg0) {
# <__main__.MutatedLineData object at 0x7a48bd5a3eb0>
# <__main__.MutatedLineData object at 0x7a48bd782800>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5a3910>
# <__main__.MutatedLineData object at 0x7a48bd5a2f50>
# <__main__.MutatedLineData object at 0x7a48bd783130>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd783ca0>
# method code ['public void actionPerformed (ActionEvent arg0) {', 'int result = JOptionPane.OK_OPTION;', '{', '}', '{', '}', '}']
# public void actionPerformed (ActionEvent arg0) {
# int result = JOptionPane.OK_OPTION;
# {
# }
# {
# }
# }
# code for ast public void actionPerformed (ActionEvent arg0) {
# int result = JOptionPane.OK_OPTION;
# {
# }
# {
# }
# }
#
# <__main__.MutatedLineData object at 0x7a48bd7825c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7815a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7814b0>
# <__main__.MutatedLineData object at 0x7a48bd4d9a50>
# <__main__.MutatedLineData object at 0x7a48bd56bd00>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd56a7a0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd569360>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd746980>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7472e0>
# <__main__.MutatedLineData object at 0x7a48bd744a30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd745060>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd54fe20>
# <__main__.MutatedLineData object at 0x7a48bd54e3b0>
# method code ['public void actionPerformed (ActionEvent e) {', '{', '{', '}{', '}', '}', '}']
# public void actionPerformed (ActionEvent e) {
# {
# {
# }{
# }
# }
# }
# code for ast public void actionPerformed (ActionEvent e) {
# {
# {
# }{
# }
# }
# }
#
# Line9: public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {
# <__main__.MutatedLineData object at 0x7a48bd2a2620>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a81c0>
# <__main__.MutatedLineData object at 0x7a48bd2a91e0>
# <__main__.MutatedLineData object at 0x7a48bd2aa4a0>
# <__main__.MutatedLineData object at 0x7a48bd2abe80>
# <__main__.MutatedLineData object at 0x7a48bd2ab550>
# <__main__.MutatedLineData object at 0x7a48bd2aae30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a8a30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a9330>
# <__main__.MutatedLineData object at 0x7a48bd2a8d30>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a94b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2abbe0>
# <__main__.MutatedLineData object at 0x7a48bd2a1180>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a0ca0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a2d40>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a35e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd2a3e80>
# <__main__.MutatedLineData object at 0x7a48bd2a05b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29f790>
# <__main__.MutatedLineData object at 0x7a48bd29ec50>
# method code ['public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {', 'String lsInsert ;', 'String lsEnd = "";', 'String lsText ;', 'Log.d ("debug");', 'Log.d ("debug");', 'lsText = dest.toString ();', '{', '{', '}', '}', 'Log.d ("debug", "loMatcher.matches(): " + loMatcher.matches () + ", lsText: " + lsText);', '{', 'return "";', '}', 'return null;', '}']
# public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {
# String lsInsert ;
# String lsEnd = "";
# String lsText ;
# Log.d ("debug");
# Log.d ("debug");
# lsText = dest.toString ();
# {
# {
# }
# }
# Log.d ("debug", "loMatcher.matches(): " + loMatcher.matches () + ", lsText: " + lsText);
# {
# return "";
# }
# return null;
# }
# code for ast public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {
# String lsInsert ;
# String lsEnd = "";
# String lsText ;
# Log.d ("debug");
# Log.d ("debug");
# lsText = dest.toString ();
# {
# {
# }
# }
# Log.d ("debug", "loMatcher.matches(): " + loMatcher.matches () + ", lsText: " + lsText);
# {
# return "";
# }
# return null;
# }
#
# <__main__.MutatedLineData object at 0x7a48bd29e110>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29d8d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd29d030>
# <__main__.MutatedLineData object at 0x7a48bd29ca90>
# <__main__.MutatedLineData object at 0x7a48bd29c490>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7aa800>
# <__main__.MutatedLineData object at 0x7a48bd7aaa10>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc018610>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc097cd0>
# <__main__.MutatedLineData object at 0x7a48bd6b5720>
# <__main__.MutatedLineData object at 0x7a48bd6b6d10>
# <__main__.MutatedLineData object at 0x7a48cc13fd60>
# <__main__.MutatedLineData object at 0x7a48cc260760>
# <__main__.MutatedLineData object at 0x7a48bd6db880>
# <__main__.MutatedLineData object at 0x7a48cc22cdc0>
# <__main__.MutatedLineData object at 0x7a48cc1e4550>
# <__main__.MutatedLineData object at 0x7a48bd56afb0>
# <__main__.MutatedLineData object at 0x7a48cc0d12d0>
# method code ['public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {', '(', '){', '{', '}', '}', '{', '{', 'return "";', '}', '{', 'return null;', '}', '{', 'return "";', '}', '}', 'return null;', '}']
# public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {
# (
# ){
# {
# }
# }
# {
# {
# return "";
# }
# {
# return null;
# }
# {
# return "";
# }
# }
# return null;
# }
# code for ast public CharSequence filter (CharSequence source, int start, int end, Spanned dest, int dstart, int dend) {
# (
# ){
# {
# }
# }
# {
# {
# return "";
# }
# {
# return null;
# }
# {
# return "";
# }
# }
# return null;
# }
#
# Line9: public static void main (String [] args) throws InterruptedException, ExecutionException {
# <__main__.MutatedLineData object at 0x7a48cc22e9b0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc22e3b0>
# do nothing
# method code ['public static void main (String [] args) throws InterruptedException, ExecutionException {', 'CompletableFuture < String > contentsCF = readPage ();', 'CompletableFuture < List < String > > linksCF = contentsCF.thenApply (CompletableFutureTest :: getLinks);', 'CompletableFuture < Void > completionStage = linksCF.thenAccept (list -> {', 'String a = null;', 'System.out.println (a.toString ());', '});', 'List < String > result = linksCF.get ();', 'System.out.println ("Got " + result);', 'try {', '} catch (ExecutionException e) {', 'System.out.println ("Caught " + e);', 'Throwable cause = e.getCause ();', 'System.out.println ("cause: " + cause);', '}', 'completionStage.exceptionally (e -> {', 'System.out.println ("Future exceptionally finished: " + e);', 'return null;', '});', 'try {', '} catch (Throwable t) {', 'System.out.println ("Already handled by the future " + t);', '}', '}']
# public static void main (String [] args) throws InterruptedException, ExecutionException {
# CompletableFuture < String > contentsCF = readPage ();
# CompletableFuture < List < String > > linksCF = contentsCF.thenApply (CompletableFutureTest :: getLinks);
# CompletableFuture < Void > completionStage = linksCF.thenAccept (list -> {
# String a = null;
# System.out.println (a.toString ());
# });
# List < String > result = linksCF.get ();
# System.out.println ("Got " + result);
# try {
# } catch (ExecutionException e) {
# System.out.println ("Caught " + e);
# Throwable cause = e.getCause ();
# System.out.println ("cause: " + cause);
# }
# completionStage.exceptionally (e -> {
# System.out.println ("Future exceptionally finished: " + e);
# return null;
# });
# try {
# } catch (Throwable t) {
# System.out.println ("Already handled by the future " + t);
# }
# }
# code for ast public static void main (String [] args) throws InterruptedException, ExecutionException {
# CompletableFuture < String > contentsCF = readPage ();
# CompletableFuture < List < String > > linksCF = contentsCF.thenApply (CompletableFutureTest :: getLinks);
# CompletableFuture < Void > completionStage = linksCF.thenAccept (list -> {
# String a = null;
# System.out.println (a.toString ());
# });
# List < String > result = linksCF.get ();
# System.out.println ("Got " + result);
# try {
# } catch (ExecutionException e) {
# System.out.println ("Caught " + e);
# Throwable cause = e.getCause ();
# System.out.println ("cause: " + cause);
# }
# completionStage.exceptionally (e -> {
# System.out.println ("Future exceptionally finished: " + e);
# return null;
# });
# try {
# } catch (Throwable t) {
# System.out.println ("Already handled by the future " + t);
# }
# }
#
# Error processing method: Clone949.java public static void main (String [] args) throws InterruptedException, ExecutionException {
# CompletableFuture < String > contentsCF = readPage ();
# CompletableFuture < List < String > > linksCF = contentsCF.thenApply (CompletableFutureTest :: getLinks);
# CompletableFuture < Void > completionStage = linksCF.thenAccept (list -> {
# String a = null;
# System.out.println (a.toString ());
# });
# List < String > result = linksCF.get ();
# System.out.println ("Got " + result);
# try {
# } catch (ExecutionException e) {
# System.out.println ("Caught " + e);
# Throwable cause = e.getCause ();
# System.out.println ("cause: " + cause);
# }
# completionStage.exceptionally (e -> {
# System.out.println ("Future exceptionally finished: " + e);
# return null;
# });
# try {
# } catch (Throwable t) {
# System.out.println ("Already handled by the future " + t);
# }
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# method code ['public static void main (String [] args) throws InterruptedException, ExecutionException {', 'CompletableFuture < String > future = readPage ();', 'CompletableFuture < Void > future2 = future.thenAccept (page -> {', 'System.out.println (page);', 'throw new IllegalArgumentException ("unexpected exception");', '});', 'future2.exceptionally (e -> {', 'e.printStackTrace (System.err);', 'return null;', '});', '}']
# public static void main (String [] args) throws InterruptedException, ExecutionException {
# CompletableFuture < String > future = readPage ();
# CompletableFuture < Void > future2 = future.thenAccept (page -> {
# System.out.println (page);
# throw new IllegalArgumentException ("unexpected exception");
# });
# future2.exceptionally (e -> {
# e.printStackTrace (System.err);
# return null;
# });
# }
# code for ast public static void main (String [] args) throws InterruptedException, ExecutionException {
# CompletableFuture < String > future = readPage ();
# CompletableFuture < Void > future2 = future.thenAccept (page -> {
# System.out.println (page);
# throw new IllegalArgumentException ("unexpected exception");
# });
# future2.exceptionally (e -> {
# e.printStackTrace (System.err);
# return null;
# });
# }
#
# Error processing method: Clone949.java public static void main (String [] args) throws InterruptedException, ExecutionException {
# CompletableFuture < String > future = readPage ();
# CompletableFuture < Void > future2 = future.thenAccept (page -> {
# System.out.println (page);
# throw new IllegalArgumentException ("unexpected exception");
# });
# future2.exceptionally (e -> {
# e.printStackTrace (System.err);
# return null;
# });
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# Line9: public static void main (String [] args) throws Exception {
# <__main__.MutatedLineData object at 0x7a48cc13c850>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13ec80>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13f700>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13e5c0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc13d7e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc018820>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc01be20>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc019690>
# do nothing
# method code ['public static void main (String [] args) throws Exception {', 'NestedMap < String, Integer > test = new NestedMap < > ();', '}']
# public static void main (String [] args) throws Exception {
# NestedMap < String, Integer > test = new NestedMap < > ();
# }
# code for ast public static void main (String [] args) throws Exception {
# NestedMap < String, Integer > test = new NestedMap < > ();
# }
#
# Error processing method: Clone758.java public static void main (String [] args) throws Exception {
# NestedMap < String, Integer > test = new NestedMap < > ();
# }
#  An unhandled error condition has been signalled: Unable to match
# (SEQ NIL (SEQ (CHILD JAVA--TYPE) (REPEAT (SEQ NIL (CHILD JAVA--TYPE)))))
# on AST of type
# JAVA-THROWS
#
#
# <__main__.MutatedLineData object at 0x7a48bd54dc90>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd56b070>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd744c10>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0572e0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc055120>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd7dfe50>
# do nothing
# <__main__.MutatedLineData object at 0x7a48bd5067d0>
# do nothing
# <__main__.MutatedLineData object at 0x7a48cc0d3f10>
# do nothing
# method code ['public static void main (String [] args) {', 'BinaryTreeWithoutRecursion < Integer > ls = new BinaryTreeWithoutRecursion < > ();', '}']
# public static void main (String [] args) {
# BinaryTreeWithoutRecursion < Integer > ls = new BinaryTreeWithoutRecursion < > ();
# }
# code for ast public static void main (String [] args) {
# BinaryTreeWithoutRecursion < Integer > ls = new BinaryTreeWithoutRecursion < > ();
# }

# %% [markdown]
# #Copy the mutated data file to google drive for download

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

# Set the source and destination directories
drive_folder = '/content/drive/My Drive/MutatedData/ValueBasedCoreDiffRemoved/'  # Change this to your Google Drive folder path

# List all files in the folder
files = os.listdir(mutated_data_folder)

# Count the number of files
file_count = len(files)

# Print the file count
print(f"Number of files in the folder: {file_count}")
# Copy each file to the Google Drive folder
for file in files:
    source_file = os.path.join(mutated_data_folder, file)
    destination_file = os.path.join(drive_folder, file)
    print(source_file,destination_file)
    shutil.copy(source_file, destination_file)

print("Files copied successfully!")
